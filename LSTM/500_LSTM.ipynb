# %%
# 資料權限
from google.colab import drive
drive.mount('/content/gdrive/',force_remount=True)
#%cd /content/drive/My-Drive/

#匯入所需套件
import numpy as np 
import matplotlib.pyplot as plt 
import pandas as pd
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation
from keras.layers.recurrent import LSTM

# 在線GPU性能检验
# !nvidia-smi
# Out:
# Mounted at /content/gdrive/
# Thu May 13 08:52:48 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 465.19.01    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   49C    P8    10W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
#匯入資料
raw = pd.read_csv('/content/gdrive/MyDrive/Colab Notebooks/test8.csv')
raw['Date'] = pd.to_datetime(raw.Date, format = '%Y/%m/%d')

#read the data
stock = raw 
amount = len(stock) #總資料筆數
stock
# Out:
#           Date        TSLA     4958.TW  ...  600885.SS        DAN         TEL
# 0   2018-06-11   66.419998   62.356850  ...  29.904634  21.776939   91.941254
# 1   2018-06-12   68.554001   61.476101  ...  30.325052  21.423853   92.215569
# 2   2018-06-13   68.956001   62.444927  ...  29.952877  20.832191   91.884514
# 3   2018-06-14   71.543999   61.476101  ...  29.692720  20.994423   93.937096
# 4   2018-06-15   71.634003   61.476101  ...  29.118149  20.813103   93.643867
# ..         ...         ...         ...  ...        ...        ...         ...
# 746 2021-04-26  738.200012  104.000000  ...  53.840000  27.290001  135.169998
# 747 2021-04-27  704.739990  106.000000  ...  54.119999  27.670000  135.149994
# 748 2021-04-28  694.400024  104.500000  ...  55.400002  27.709999  135.919998
# 749 2021-04-29  677.000000  106.000000  ...  56.290001  26.459999  138.179993
# 750 2021-04-30  709.440002  106.000000  ...  55.919998  25.299999  134.470001
#
# [751 rows x 11 columns]

# %%
#設定資料之input variable (X) 與target variable (Y)。如以被預測日前ref_day天作為input variables，以被預測日做為target variable
def xy_set(dataset, ref_day):
    predict_day=1 #predict_day:被預測天數
    X = [[0 for i in range(ref_day)] for j in range(dataset.shape[0]-predict_day-ref_day)] #宣告輸入變數空集合
    Y = [0 for j in range(dataset.shape[0]-predict_day-ref_day)] #宣告被預測變數空集合
    for i in range(dataset.shape[0]-predict_day-ref_day):
        X[i] = dataset[i:i+ref_day,0] #前ref_day天資料
        Y[i] = dataset[i+ref_day:i+ref_day+predict_day,0] #第ref_day+1天資料
    return np.array(X),np.array(Y)

# %%
def show_train_history(train_history,train,validation):
   #train_history訓練過程；train訓練結果；validation驗證結果

      plt.plot(train_history.history[train]) #描繪訓練結果
      plt.plot(train_history.history[validation]) #描繪驗證結果
      plt.title('Train History') #圖標題
      plt.ylabel(train) #y軸標籤
      plt.xlabel('Epoch') #x軸標籤
      plt.legend(['train', 'validation'], loc='upper left') #設定訓練與驗證之圖例及位置
      plt.show()

# %%
## 預設參數
ref_day = 5 #ref_day:預測參照天數
d = 0.2
dim= stock.shape[1]#-1
# %pylab inline
#讓圖形直接顯示於jupyter note

rdf= pd.DataFrame() #用于保存所有股票的预测价格

## 
from sklearn import preprocessing #使用sklearn的preprocessing的MinMaxScaler進行正規化:(x-min)/(max-min)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
def show_test_result(Real_data,Prediciton_data):
    plt.plot(Real_data, color="red", label="Real Stock Price") #描繪測試資料真實股價
    plt.plot(Prediciton_data, color="blue", label="Predicted Stock Price") #描繪測試資料預測股價
    plt.title('Stock Prediction')
    plt.ylabel('Price') 
    plt.xlabel('Time') 
    plt.legend()
    plt.show()

# %%
stock.shape
for i in range(stock.shape[1]-1):
  n= i+1
  stock_set = stock[stock.columns[n]] 

  #分割訓練資料與測試資料
  length = len(stock[stock.Date<'2020/05/13'])-ref_day #決定分割時間點，例如以2019-03-20之前ref_day天以前之有交易記錄的資料為training set
  train = stock_set[0:length] #決定資料分割時間點，例如以2021-01-31前ref_day天起為testing set
  test = stock_set[length:]

  #使用sklearn的preprocessing的MinMaxScaler進行正規化:(x-min)/(max-min)
  #執行正規化
  train = train.values.reshape(-1,1) #執行reshape，使其shape為(資料長度,1)
  scaler= preprocessing.MinMaxScaler(feature_range=(0, 1)).fit(train)
  train_nom = scaler.transform(train) #執行正規化，使得特徵值範圍介於0~1

  X_train, Y_train = xy_set(train_nom, ref_day) #區分訓練資料之input variables與output variable
  X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1)) # 轉成三維，以便符合keras recurrent之input_shape
  Y_train = np.squeeze(Y_train)
  print('輸入變數維度',X_train.shape)
  print('預測變數維度',Y_train.shape)
  print('第Y個被預測日之前ref_day天每天正規化股價')
  print(X_train[4])
  print('第Y個預測日之正規化股價')
  print(Y_train[4])

  model = Sequential()
  model.add(LSTM(units=256, activation="relu", return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2])))
  model.add(Dropout(d))
  model.add(LSTM(units=256, activation="relu", return_sequences=True, input_shape=(X_train.shape[1], dim)))
  model.add(Dropout(d))
  model.add(LSTM(units=256, activation="relu", return_sequences=True, input_shape=(X_train.shape[1], dim)))
  model.add(Dropout(d))
  model.add(LSTM(units=256, activation="relu", return_sequences=True, input_shape=(X_train.shape[1], dim)))
  model.add(Dropout(d))
  model.add(LSTM(units=256, activation="relu", return_sequences=False, input_shape=(X_train.shape[1], dim)))
  model.add(Dropout(d))  
  model.add(Dense(units=1))
      #model.compile(optimizer='adam', loss='mse')  # rmsprop
      #model.compile(loss="mean_squared_error", optimizer="adam",metrics=['mean_squared_error']) 
      # 屬迴歸分析，通常使用Mean Squared Error或Mean Absolute Error
  model.compile(loss="mean_absolute_error", optimizer="adam",metrics=['mean_absolute_error'])
  model.summary()
  train_history =model.fit(X_train, Y_train,batch_size=32,  
                         epochs=100,verbose=1,validation_split=0.2)
  
  show_train_history(train_history,'mean_absolute_error','val_mean_absolute_error')

  #分割訓練資料與測試資料
  length = len(stock[stock.Date<'2020/05/13'])-ref_day #決定分割時間點，例如以2021-01-31之前的ref_day天以後之有交易記錄的資料為testing set
  test = stock_set[length:]
  #執行正規化
  test = test.values.reshape(-1,1) #執行reshape，使其shape為(資料長度,1)
  test_scaler= preprocessing.MinMaxScaler(feature_range=(0, 1)).fit(test)
  test_nom = test_scaler.transform(test) #執行正規化，使得特徵值範圍介於0~1

  X_test, Y_test = xy_set(test_nom, ref_day) #區分訓練資料之input variables與output variable
  X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1)) # 轉成三維，以便符合keras recurrent之input_shape
  Y_test = np.squeeze(Y_test)
  print('輸入變數維度',X_test.shape)
  print('預測變數維度',Y_test.shape)
  print('第Y個被預測日之前ref_day天每天正規化股價')
  print(X_test[4])
  print('第Y個預測日之正規化股價')
  print(Y_test[4])

  scores = model.evaluate(X_test, Y_test, verbose=1) #使用model.evaluate進行模型評估，評估後的績效指標會儲存於scores
  scores[1] #傳回測試資料的mean_absolute_error

  Y_test_predict=model.predict(X_test) #測試資料預測結果
  Y_test_predict_price = test_scaler.inverse_transform(Y_test_predict) # 將正規化預測值轉換為股票價格

  X_test_real, Y_test_real = xy_set(test, ref_day) #取得測試資料之被預測日之真實股票價格
  show_test_result(Y_test_real,Y_test_predict_price) #結果若不錯，代表可以使用此模型預測某支股票的股價

  col= stock.columns[n] 
  result= pd.DataFrame(Y_test_predict_price, columns= [col])
  rdf= pd.concat([rdf, result], axis=1)
# Out:
# 輸入變數維度 (489, 5, 1)
# 預測變數維度 (489,)
# 第Y個被預測日之前ref_day天每天正規化股價
# [[0.24267049]
#  [0.2598145 ]
#  [0.23505995]
#  [0.24815494]
#  [0.22823483]]
# 第Y個預測日之正規化股價
# 0.20943869113080396
# WARNING:tensorflow:Layer lstm will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# WARNING:tensorflow:Layer lstm_2 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# WARNING:tensorflow:Layer lstm_3 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# WARNING:tensorflow:Layer lstm_4 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 5, 256)            264192
# _________________________________________________________________
# dropout (Dropout)            (None, 5, 256)            0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 5, 256)            525312
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 5, 256)            0
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 5, 256)            525312
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 5, 256)            0
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 5, 256)            525312
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 5, 256)            0
# _________________________________________________________________
# lstm_4 (LSTM)                (None, 256)               525312
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 257
# =================================================================
# Total params: 2,365,697
# Trainable params: 2,365,697
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 13/13 [==============================] - 8s 118ms/step - loss: 0.1127 - mean_absolute_error: 0.1127 - val_loss: 0.4330 - val_mean_absolute_error: 0.4330
# Epoch 2/100
# 13/13 [==============================] - 1s 51ms/step - loss: 0.0560 - mean_absolute_error: 0.0560 - val_loss: 0.4158 - val_mean_absolute_error: 0.4158
# Epoch 3/100
# 13/13 [==============================] - 1s 46ms/step - loss: 0.0563 - mean_absolute_error: 0.0563 - val_loss: 0.4401 - val_mean_absolute_error: 0.4401
# Epoch 4/100
# 13/13 [==============================] - 1s 47ms/step - loss: 0.0508 - mean_absolute_error: 0.0508 - val_loss: 0.2579 - val_mean_absolute_error: 0.2579
# Epoch 5/100
# 13/13 [==============================] - 1s 48ms/step - loss: 0.0300 - mean_absolute_error: 0.0300 - val_loss: 0.1220 - val_mean_absolute_error: 0.1220
# Epoch 6/100
# 13/13 [==============================] - 1s 50ms/step - loss: 0.0233 - mean_absolute_error: 0.0233 - val_loss: 0.1001 - val_mean_absolute_error: 0.1001
# Epoch 7/100
# 13/13 [==============================] - 1s 47ms/step - loss: 0.0235 - mean_absolute_error: 0.0235 - val_loss: 0.1192 - val_mean_absolute_error: 0.1192
# Epoch 8/100
# 13/13 [==============================] - 1s 47ms/step - loss: 0.0215 - mean_absolute_error: 0.0215 - val_loss: 0.1548 - val_mean_absolute_error: 0.1548
# Epoch 9/100
# 13/13 [==============================] - 1s 46ms/step - loss: 0.0226 - mean_absolute_error: 0.0226 - val_loss: 0.1156 - val_mean_absolute_error: 0.1156
# Epoch 10/100
# 13/13 [==============================] - 1s 48ms/step - loss: 0.0219 - mean_absolute_error: 0.0219 - val_loss: 0.1293 - val_mean_absolute_error: 0.1293
# Epoch 11/100
# 13/13 [==============================] - 1s 49ms/step - loss: 0.0233 - mean_absolute_error: 0.0233 - val_loss: 0.2112 - val_mean_absolute_error: 0.2112
# Epoch 12/100
# 13/13 [==============================] - 1s 47ms/step - loss: 0.0290 - mean_absolute_error: 0.0290 - val_loss: 0.0907 - val_mean_absolute_error: 0.0907
# Epoch 13/100
# 13/13 [==============================] - 1s 49ms/step - loss: 0.0298 - mean_absolute_error: 0.0298 - val_loss: 0.1736 - val_mean_absolute_error: 0.1736
# Epoch 14/100
# 13/13 [==============================] - 1s 49ms/step - loss: 0.0228 - mean_absolute_error: 0.0228 - val_loss: 0.1728 - val_mean_absolute_error: 0.1728
# Epoch 15/100
# 13/13 [==============================] - 1s 46ms/step - loss: 0.0242 - mean_absolute_error: 0.0242 - val_loss: 0.1690 - val_mean_absolute_error: 0.1690
# Epoch 16/100
# 13/13 [==============================] - 1s 48ms/step - loss: 0.0224 - mean_absolute_error: 0.0224 - val_loss: 0.1858 - val_mean_absolute_error: 0.1858
# Epoch 17/100
# 13/13 [==============================] - 1s 50ms/step - loss: 0.0233 - mean_absolute_error: 0.0233 - val_loss: 0.1632 - val_mean_absolute_error: 0.1632
# Epoch 18/100
# 13/13 [==============================] - 1s 47ms/step - loss: 0.0224 - mean_absolute_error: 0.0224 - val_loss: 0.1687 - val_mean_absolute_error: 0.1687
# Epoch 19/100
# 13/13 [==============================] - 1s 49ms/step - loss: 0.0212 - mean_absolute_error: 0.0212 - val_loss: 0.1514 - val_mean_absolute_error: 0.1514
# Epoch 20/100
# 13/13 [==============================] - 1s 48ms/step - loss: 0.0197 - mean_absolute_error: 0.0197 - val_loss: 0.1609 - val_mean_absolute_error: 0.1609
# Epoch 21/100
# 13/13 [==============================] - 1s 49ms/step - loss: 0.0196 - mean_absolute_error: 0.0196 - val_loss: 0.1685 - val_mean_absolute_error: 0.1685
# Epoch 22/100
# 13/13 [==============================] - 1s 50ms/step - loss: 0.0251 - mean_absolute_error: 0.0251 - val_loss: 0.1774 - val_mean_absolute_error: 0.1774
# Epoch 23/100
# 13/13 [==============================] - 1s 47ms/step - loss: 0.0239 - mean_absolute_error: 0.0239 - val_loss: 0.1823 - val_mean_absolute_error: 0.1823
# Epoch 24/100
# 13/13 [==============================] - 1s 47ms/step - loss: 0.0208 - mean_absolute_error: 0.0208 - val_loss: 0.1745 - val_mean_absolute_error: 0.1745
# Epoch 25/100
# 13/13 [==============================] - 1s 49ms/step - loss: 0.0214 - mean_absolute_error: 0.0214 - val_loss: 0.1710 - val_mean_absolute_error: 0.1710
# Epoch 26/100
# 13/13 [==============================] - 1s 50ms/step - loss: 0.0194 - mean_absolute_error: 0.0194 - val_loss: 0.1781 - val_mean_absolute_error: 0.1781
# Epoch 27/100
# 13/13 [==============================] - 1s 51ms/step - loss: 0.0212 - mean_absolute_error: 0.0212 - val_loss: 0.1746 - val_mean_absolute_error: 0.1746
# Epoch 28/100
# 13/13 [==============================] - 1s 50ms/step - loss: 0.0210 - mean_absolute_error: 0.0210 - val_loss: 0.1775 - val_mean_absolute_error: 0.1775
# Epoch 29/100
# 13/13 [==============================] - 1s 46ms/step - loss: 0.0239 - mean_absolute_error: 0.0239 - val_loss: 0.2021 - val_mean_absolute_error: 0.2021
# Epoch 30/100
# 13/13 [==============================] - 1s 45ms/step - loss: 0.0214 - mean_absolute_error: 0.0214 - val_loss: 0.1774 - val_mean_absolute_error: 0.1774
# Epoch 31/100
# 13/13 [==============================] - 1s 46ms/step - loss: 0.0203 - mean_absolute_error: 0.0203 - val_loss: 0.2001 - val_mean_absolute_error: 0.2001
# Epoch 32/100
# 13/13 [==============================] - 1s 48ms/step - loss: 0.0207 - mean_absolute_error: 0.0207 - val_loss: 0.1664 - val_mean_absolute_error: 0.1664
# Epoch 33/100
# 13/13 [==============================] - 1s 46ms/step - loss: 0.0205 - mean_absolute_error: 0.0205 - val_loss: 0.1890 - val_mean_absolute_error: 0.1890
# Epoch 34/100
# 13/13 [==============================] - 1s 45ms/step - loss: 0.0212 - mean_absolute_error: 0.0212 - val_loss: 0.1836 - val_mean_absolute_error: 0.1836
# Epoch 35/100
# 13/13 [==============================] - 1s 45ms/step - loss: 0.0246 - mean_absolute_error: 0.0246 - val_loss: 0.1953 - val_mean_absolute_error: 0.1953
# Epoch 36/100
# 13/13 [==============================] - 1s 51ms/step - loss: 0.0201 - mean_absolute_error: 0.0201 - val_loss: 0.1736 - val_mean_absolute_error: 0.1736
# Epoch 37/100
# 13/13 [==============================] - 1s 47ms/step - loss: 0.0227 - mean_absolute_error: 0.0227 - val_loss: 0.2025 - val_mean_absolute_error: 0.2025
# Epoch 38/100
# 13/13 [==============================] - 1s 48ms/step - loss: 0.0190 - mean_absolute_error: 0.0190 - val_loss: 0.2151 - val_mean_absolute_error: 0.2151
# Epoch 39/100
# 13/13 [==============================] - 1s 48ms/step - loss: 0.0200 - mean_absolute_error: 0.0200 - val_loss: 0.1853 - val_mean_absolute_error: 0.1853
# Epoch 40/100
# 13/13 [==============================] - 1s 49ms/step - loss: 0.0192 - mean_absolute_error: 0.0192 - val_loss: 0.1774 - val_mean_absolute_error: 0.1774
# Epoch 41/100
# 13/13 [==============================] - 1s 48ms/step - loss: 0.0190 - mean_absolute_error: 0.0190 - val_loss: 0.2040 - val_mean_absolute_error: 0.2040
# Epoch 42/100
# 13/13 [==============================] - 1s 48ms/step - loss: 0.0195 - mean_absolute_error: 0.0195 - val_loss: 0.1717 - val_mean_absolute_error: 0.1717
# Epoch 43/100
# 13/13 [==============================] - 1s 50ms/step - loss: 0.0202 - mean_absolute_error: 0.0202 - val_loss: 0.2023 - val_mean_absolute_error: 0.2023
# Epoch 44/100
# 13/13 [==============================] - 1s 51ms/step - loss: 0.0202 - mean_absolute_error: 0.0202 - val_loss: 0.1777 - val_mean_absolute_error: 0.1777
# Epoch 45/100
# 13/13 [==============================] - 1s 46ms/step - loss: 0.0192 - mean_absolute_error: 0.0192 - val_loss: 0.1864 - val_mean_absolute_error: 0.1864
# Epoch 46/100
# 13/13 [==============================] - 1s 47ms/step - loss: 0.0193 - mean_absolute_error: 0.0193 - val_loss: 0.1583 - val_mean_absolute_error: 0.1583
# Epoch 47/100
# 13/13 [==============================] - 1s 46ms/step - loss: 0.0190 - mean_absolute_error: 0.0190 - val_loss: 0.1770 - val_mean_absolute_error: 0.1770
# Epoch 48/100
# 13/13 [==============================] - 1s 45ms/step - loss: 0.0202 - mean_absolute_error: 0.0202 - val_loss: 0.1911 - val_mean_absolute_error: 0.1911
# Epoch 49/100
# 13/13 [==============================] - 1s 49ms/step - loss: 0.0221 - mean_absolute_error: 0.0221 - val_loss: 0.1481 - val_mean_absolute_error: 0.1481
# Epoch 50/100
# 13/13 [==============================] - 1s 48ms/step - loss: 0.0227 - mean_absolute_error: 0.0227 - val_loss: 0.1940 - val_mean_absolute_error: 0.1940
# Epoch 51/100
# 13/13 [==============================] - 1s 47ms/step - loss: 0.0201 - mean_absolute_error: 0.0201 - val_loss: 0.1606 - val_mean_absolute_error: 0.1606
# Epoch 52/100
# 13/13 [==============================] - 1s 48ms/step - loss: 0.0208 - mean_absolute_error: 0.0208 - val_loss: 0.2075 - val_mean_absolute_error: 0.2075
# Epoch 53/100
# 13/13 [==============================] - 1s 50ms/step - loss: 0.0208 - mean_absolute_error: 0.0208 - val_loss: 0.1946 - val_mean_absolute_error: 0.1946
# Epoch 54/100
# 13/13 [==============================] - 1s 47ms/step - loss: 0.0193 - mean_absolute_error: 0.0193 - val_loss: 0.1944 - val_mean_absolute_error: 0.1944
# Epoch 55/100
# 13/13 [==============================] - 1s 46ms/step - loss: 0.0187 - mean_absolute_error: 0.0187 - val_loss: 0.1933 - val_mean_absolute_error: 0.1933
# Epoch 56/100
# 13/13 [==============================] - 1s 48ms/step - loss: 0.0196 - mean_absolute_error: 0.0196 - val_loss: 0.2169 - val_mean_absolute_error: 0.2169
# Epoch 57/100
# 13/13 [==============================] - 1s 48ms/step - loss: 0.0200 - mean_absolute_error: 0.0200 - val_loss: 0.1919 - val_mean_absolute_error: 0.1919
# Epoch 58/100
# 13/13 [==============================] - 1s 47ms/step - loss: 0.0199 - mean_absolute_error: 0.0199 - val_loss: 0.2029 - val_mean_absolute_error: 0.2029
# Epoch 59/100
# 13/13 [==============================] - 1s 47ms/step - loss: 0.0187 - mean_absolute_error: 0.0187 - val_loss: 0.1718 - val_mean_absolute_error: 0.1718
# Epoch 60/100
# 13/13 [==============================] - 1s 52ms/step - loss: 0.0186 - mean_absolute_error: 0.0186 - val_loss: 0.2085 - val_mean_absolute_error: 0.2085
# Epoch 61/100
# 13/13 [==============================] - 1s 49ms/step - loss: 0.0193 - mean_absolute_error: 0.0193 - val_loss: 0.1792 - val_mean_absolute_error: 0.1792
# Epoch 62/100
# 13/13 [==============================] - 1s 53ms/step - loss: 0.0203 - mean_absolute_error: 0.0203 - val_loss: 0.2181 - val_mean_absolute_error: 0.2181
# Epoch 63/100
# 13/13 [==============================] - 1s 47ms/step - loss: 0.0189 - mean_absolute_error: 0.0189 - val_loss: 0.1898 - val_mean_absolute_error: 0.1898
# Epoch 64/100
# 13/13 [==============================] - 1s 46ms/step - loss: 0.0185 - mean_absolute_error: 0.0185 - val_loss: 0.2106 - val_mean_absolute_error: 0.2106
# Epoch 65/100
# 13/13 [==============================] - 1s 48ms/step - loss: 0.0168 - mean_absolute_error: 0.0168 - val_loss: 0.1993 - val_mean_absolute_error: 0.1993
# Epoch 66/100
# 13/13 [==============================] - 1s 49ms/step - loss: 0.0187 - mean_absolute_error: 0.0187 - val_loss: 0.2021 - val_mean_absolute_error: 0.2021
# Epoch 67/100
# 13/13 [==============================] - 1s 46ms/step - loss: 0.0183 - mean_absolute_error: 0.0183 - val_loss: 0.2014 - val_mean_absolute_error: 0.2014
# Epoch 68/100
# 13/13 [==============================] - 1s 50ms/step - loss: 0.0182 - mean_absolute_error: 0.0182 - val_loss: 0.1644 - val_mean_absolute_error: 0.1644
# Epoch 69/100
# 13/13 [==============================] - 1s 49ms/step - loss: 0.0235 - mean_absolute_error: 0.0235 - val_loss: 0.2021 - val_mean_absolute_error: 0.2021
# Epoch 70/100
# 13/13 [==============================] - 1s 49ms/step - loss: 0.0211 - mean_absolute_error: 0.0211 - val_loss: 0.2360 - val_mean_absolute_error: 0.2360
# Epoch 71/100
# 13/13 [==============================] - 1s 50ms/step - loss: 0.0196 - mean_absolute_error: 0.0196 - val_loss: 0.2142 - val_mean_absolute_error: 0.2142
# Epoch 72/100
# 13/13 [==============================] - 1s 49ms/step - loss: 0.0202 - mean_absolute_error: 0.0202 - val_loss: 0.1933 - val_mean_absolute_error: 0.1933
# Epoch 73/100
# 13/13 [==============================] - 1s 46ms/step - loss: 0.0209 - mean_absolute_error: 0.0209 - val_loss: 0.2488 - val_mean_absolute_error: 0.2488
# Epoch 74/100
# 13/13 [==============================] - 1s 50ms/step - loss: 0.0215 - mean_absolute_error: 0.0215 - val_loss: 0.2632 - val_mean_absolute_error: 0.2632
# Epoch 75/100
# 13/13 [==============================] - 1s 50ms/step - loss: 0.0208 - mean_absolute_error: 0.0208 - val_loss: 0.2182 - val_mean_absolute_error: 0.2182
# Epoch 76/100
# 13/13 [==============================] - 1s 49ms/step - loss: 0.0187 - mean_absolute_error: 0.0187 - val_loss: 0.2395 - val_mean_absolute_error: 0.2395
# Epoch 77/100
# 13/13 [==============================] - 1s 47ms/step - loss: 0.0178 - mean_absolute_error: 0.0178 - val_loss: 0.2344 - val_mean_absolute_error: 0.2344
# Epoch 78/100
# 13/13 [==============================] - 1s 48ms/step - loss: 0.0184 - mean_absolute_error: 0.0184 - val_loss: 0.2092 - val_mean_absolute_error: 0.2092
# Epoch 79/100
# 13/13 [==============================] - 1s 51ms/step - loss: 0.0194 - mean_absolute_error: 0.0194 - val_loss: 0.2362 - val_mean_absolute_error: 0.2362
# Epoch 80/100
# 13/13 [==============================] - 1s 51ms/step - loss: 0.0182 - mean_absolute_error: 0.0182 - val_loss: 0.2294 - val_mean_absolute_error: 0.2294
# Epoch 81/100
# 13/13 [==============================] - 1s 46ms/step - loss: 0.0169 - mean_absolute_error: 0.0169 - val_loss: 0.2344 - val_mean_absolute_error: 0.2344
# Epoch 82/100
# 13/13 [==============================] - 1s 48ms/step - loss: 0.0179 - mean_absolute_error: 0.0179 - val_loss: 0.2194 - val_mean_absolute_error: 0.2194
# Epoch 83/100
# 13/13 [==============================] - 1s 48ms/step - loss: 0.0184 - mean_absolute_error: 0.0184 - val_loss: 0.2412 - val_mean_absolute_error: 0.2412
# Epoch 84/100
# 13/13 [==============================] - 1s 49ms/step - loss: 0.0160 - mean_absolute_error: 0.0160 - val_loss: 0.2413 - val_mean_absolute_error: 0.2413
# Epoch 85/100
# 13/13 [==============================] - 1s 50ms/step - loss: 0.0147 - mean_absolute_error: 0.0147 - val_loss: 0.2171 - val_mean_absolute_error: 0.2171
# Epoch 86/100
# 13/13 [==============================] - 1s 47ms/step - loss: 0.0163 - mean_absolute_error: 0.0163 - val_loss: 0.2508 - val_mean_absolute_error: 0.2508
# Epoch 87/100
# 13/13 [==============================] - 1s 47ms/step - loss: 0.0158 - mean_absolute_error: 0.0158 - val_loss: 0.2465 - val_mean_absolute_error: 0.2465
# Epoch 88/100
# 13/13 [==============================] - 1s 48ms/step - loss: 0.0178 - mean_absolute_error: 0.0178 - val_loss: 0.2586 - val_mean_absolute_error: 0.2586
# Epoch 89/100
# 13/13 [==============================] - 1s 45ms/step - loss: 0.0168 - mean_absolute_error: 0.0168 - val_loss: 0.2539 - val_mean_absolute_error: 0.2539
# Epoch 90/100
# 13/13 [==============================] - 1s 50ms/step - loss: 0.0160 - mean_absolute_error: 0.0160 - val_loss: 0.2335 - val_mean_absolute_error: 0.2335
# Epoch 91/100
# 13/13 [==============================] - 1s 49ms/step - loss: 0.0168 - mean_absolute_error: 0.0168 - val_loss: 0.2207 - val_mean_absolute_error: 0.2207
# Epoch 92/100
# 13/13 [==============================] - 1s 50ms/step - loss: 0.0160 - mean_absolute_error: 0.0160 - val_loss: 0.2432 - val_mean_absolute_error: 0.2432
# Epoch 93/100
# 13/13 [==============================] - 1s 51ms/step - loss: 0.0153 - mean_absolute_error: 0.0153 - val_loss: 0.2490 - val_mean_absolute_error: 0.2490
# Epoch 94/100
# 13/13 [==============================] - 1s 50ms/step - loss: 0.0151 - mean_absolute_error: 0.0151 - val_loss: 0.2392 - val_mean_absolute_error: 0.2392
# Epoch 95/100
# 13/13 [==============================] - 1s 50ms/step - loss: 0.0166 - mean_absolute_error: 0.0166 - val_loss: 0.2678 - val_mean_absolute_error: 0.2678
# Epoch 96/100
# 13/13 [==============================] - 1s 47ms/step - loss: 0.0162 - mean_absolute_error: 0.0162 - val_loss: 0.2638 - val_mean_absolute_error: 0.2638
# Epoch 97/100
# 13/13 [==============================] - 1s 46ms/step - loss: 0.0167 - mean_absolute_error: 0.0167 - val_loss: 0.2527 - val_mean_absolute_error: 0.2527
# Epoch 98/100
# 13/13 [==============================] - 1s 50ms/step - loss: 0.0156 - mean_absolute_error: 0.0156 - val_loss: 0.2278 - val_mean_absolute_error: 0.2278
# Epoch 99/100
# 13/13 [==============================] - 1s 45ms/step - loss: 0.0175 - mean_absolute_error: 0.0175 - val_loss: 0.2582 - val_mean_absolute_error: 0.2582
# Epoch 100/100
# 13/13 [==============================] - 1s 46ms/step - loss: 0.0154 - mean_absolute_error: 0.0154 - val_loss: 0.2376 - val_mean_absolute_error: 0.2376
# 輸入變數維度 (250, 5, 1)
# 預測變數維度 (250,)
# 第Y個被預測日之前ref_day天每天正規化股價
# [[0.00807888]
#  [0.0030038 ]
#  [0.00640644]
#  [0.00526214]
#  [0.00923968]]
# 第Y個預測日之正規化股價
# 0.0076937802874826045
# 8/8 [==============================] - 0s 5ms/step - loss: 0.1977 - mean_absolute_error: 0.1977
# 輸入變數維度 (489, 5, 1)
# 預測變數維度 (489,)
# 第Y個被預測日之前ref_day天每天正規化股價
# [[0.04567084]
#  [0.04567084]
#  [0.0349819 ]
#  [0.02429296]
#  [0.03886883]]
# 第Y個預測日之正規化股價
# 0.027208136372076752
# WARNING:tensorflow:Layer lstm_5 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# WARNING:tensorflow:Layer lstm_6 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# WARNING:tensorflow:Layer lstm_7 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# WARNING:tensorflow:Layer lstm_8 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# WARNING:tensorflow:Layer lstm_9 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_5 (LSTM)                (None, 5, 256)            264192
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 5, 256)            0
# _________________________________________________________________
# lstm_6 (LSTM)                (None, 5, 256)            525312
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 5, 256)            0
# _________________________________________________________________
# lstm_7 (LSTM)                (None, 5, 256)            525312
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 5, 256)            0
# _________________________________________________________________
# lstm_8 (LSTM)                (None, 5, 256)            525312
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 5, 256)            0
# _________________________________________________________________
# lstm_9 (LSTM)                (None, 256)               525312
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 2,365,697
# Trainable params: 2,365,697
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 13/13 [==============================] - 5s 93ms/step - loss: 0.2857 - mean_absolute_error: 0.2857 - val_loss: 0.1788 - val_mean_absolute_error: 0.1788
# Epoch 2/100
# 13/13 [==============================] - 1s 46ms/step - loss: 0.2009 - mean_absolute_error: 0.2009 - val_loss: 0.0644 - val_mean_absolute_error: 0.0644
# Epoch 3/100
# 13/13 [==============================] - 1s 49ms/step - loss: 0.0952 - mean_absolute_error: 0.0952 - val_loss: 0.0832 - val_mean_absolute_error: 0.0832
# Epoch 4/100
# 13/13 [==============================] - 1s 53ms/step - loss: 0.0571 - mean_absolute_error: 0.0571 - val_loss: 0.0855 - val_mean_absolute_error: 0.0855
# Epoch 5/100
# 13/13 [==============================] - 1s 47ms/step - loss: 0.0457 - mean_absolute_error: 0.0457 - val_loss: 0.0591 - val_mean_absolute_error: 0.0591
# Epoch 6/100
# 13/13 [==============================] - 1s 48ms/step - loss: 0.0443 - mean_absolute_error: 0.0443 - val_loss: 0.1002 - val_mean_absolute_error: 0.1002
# Epoch 7/100
# 13/13 [==============================] - 1s 46ms/step - loss: 0.0488 - mean_absolute_error: 0.0488 - val_loss: 0.0954 - val_mean_absolute_error: 0.0954
# Epoch 8/100
# 13/13 [==============================] - 1s 51ms/step - loss: 0.0462 - mean_absolute_error: 0.0462 - val_loss: 0.0595 - val_mean_absolute_error: 0.0595
# Epoch 9/100
# 13/13 [==============================] - 1s 49ms/step - loss: 0.0478 - mean_absolute_error: 0.0478 - val_loss: 0.0642 - val_mean_absolute_error: 0.0642
# Epoch 10/100
# 13/13 [==============================] - 1s 47ms/step - loss: 0.0407 - mean_absolute_error: 0.0407 - val_loss: 0.0619 - val_mean_absolute_error: 0.0619
# Epoch 11/100
# 13/13 [==============================] - 1s 50ms/step - loss: 0.0424 - mean_absolute_error: 0.0424 - val_loss: 0.1391 - val_mean_absolute_error: 0.1391
# Epoch 12/100
# 13/13 [==============================] - 1s 50ms/step - loss: 0.0663 - mean_absolute_error: 0.0663 - val_loss: 0.0723 - val_mean_absolute_error: 0.0723
# Epoch 13/100
# 13/13 [==============================] - 1s 47ms/step - loss: 0.0419 - mean_absolute_error: 0.0419 - val_loss: 0.0628 - val_mean_absolute_error: 0.0628
# Epoch 14/100
# 13/13 [==============================] - 1s 51ms/step - loss: 0.0372 - mean_absolute_error: 0.0372 - val_loss: 0.0794 - val_mean_absolute_error: 0.0794
# Epoch 15/100
# 13/13 [==============================] - 1s 46ms/step - loss: 0.0472 - mean_absolute_error: 0.0472 - val_loss: 0.0649 - val_mean_absolute_error: 0.0649
# Epoch 16/100
# 13/13 [==============================] - 1s 49ms/step - loss: 0.0478 - mean_absolute_error: 0.0478 - val_loss: 0.0593 - val_mean_absolute_error: 0.0593
# Epoch 17/100
# 13/13 [==============================] - 1s 45ms/step - loss: 0.0394 - mean_absolute_error: 0.0394 - val_loss: 0.0593 - val_mean_absolute_error: 0.0593
# Epoch 18/100
# 13/13 [==============================] - 1s 47ms/step - loss: 0.0438 - mean_absolute_error: 0.0438 - val_loss: 0.0973 - val_mean_absolute_error: 0.0973
# Epoch 19/100
# 13/13 [==============================] - 1s 48ms/step - loss: 0.0489 - mean_absolute_error: 0.0489 - val_loss: 0.0753 - val_mean_absolute_error: 0.0753
# Epoch 20/100
# 13/13 [==============================] - 1s 51ms/step - loss: 0.0483 - mean_absolute_error: 0.0483 - val_loss: 0.0878 - val_mean_absolute_error: 0.0878
# Epoch 21/100
# 13/13 [==============================] - 1s 48ms/step - loss: 0.0551 - mean_absolute_error: 0.0551 - val_loss: 0.0600 - val_mean_absolute_error: 0.0600
# Epoch 22/100
# 13/13 [==============================] - 1s 49ms/step - loss: 0.0421 - mean_absolute_error: 0.0421 - val_loss: 0.0621 - val_mean_absolute_error: 0.0621
# Epoch 23/100
# 13/13 [==============================] - 1s 49ms/step - loss: 0.0421 - mean_absolute_error: 0.0421 - val_loss: 0.0605 - val_mean_absolute_error: 0.0605
# Epoch 24/100
# 13/13 [==============================] - 1s 48ms/step - loss: 0.0474 - mean_absolute_error: 0.0474 - val_loss: 0.0584 - val_mean_absolute_error: 0.0584
# Epoch 25/100
# 13/13 [==============================] - 1s 51ms/step - loss: 0.0432 - mean_absolute_error: 0.0432 - val_loss: 0.0590 - val_mean_absolute_error: 0.0590
# Epoch 26/100
# 13/13 [==============================] - 1s 48ms/step - loss: 0.0358 - mean_absolute_error: 0.0358 - val_loss: 0.0662 - val_mean_absolute_error: 0.0662
# Epoch 27/100
# 13/13 [==============================] - 1s 48ms/step - loss: 0.0422 - mean_absolute_error: 0.0422 - val_loss: 0.0612 - val_mean_absolute_error: 0.0612
# Epoch 28/100
# 13/13 [==============================] - 1s 49ms/step - loss: 0.0377 - mean_absolute_error: 0.0377 - val_loss: 0.0582 - val_mean_absolute_error: 0.0582
# Epoch 29/100
# 13/13 [==============================] - 1s 48ms/step - loss: 0.0389 - mean_absolute_error: 0.0389 - val_loss: 0.0592 - val_mean_absolute_error: 0.0592
# Epoch 30/100
# 13/13 [==============================] - 1s 48ms/step - loss: 0.0349 - mean_absolute_error: 0.0349 - val_loss: 0.0580 - val_mean_absolute_error: 0.0580
# Epoch 31/100
# 13/13 [==============================] - 1s 49ms/step - loss: 0.0426 - mean_absolute_error: 0.0426 - val_loss: 0.0579 - val_mean_absolute_error: 0.0579
# Epoch 32/100
# 13/13 [==============================] - 1s 48ms/step - loss: 0.0413 - mean_absolute_error: 0.0413 - val_loss: 0.0738 - val_mean_absolute_error: 0.0738
# Epoch 33/100
# 13/13 [==============================] - 1s 49ms/step - loss: 0.0496 - mean_absolute_error: 0.0496 - val_loss: 0.0591 - val_mean_absolute_error: 0.0591
# Epoch 34/100
# 13/13 [==============================] - 1s 49ms/step - loss: 0.0371 - mean_absolute_error: 0.0371 - val_loss: 0.0597 - val_mean_absolute_error: 0.0597
# Epoch 35/100
# 13/13 [==============================] - 1s 46ms/step - loss: 0.0394 - mean_absolute_error: 0.0394 - val_loss: 0.0603 - val_mean_absolute_error: 0.0603
# Epoch 36/100
# 13/13 [==============================] - 1s 45ms/step - loss: 0.0367 - mean_absolute_error: 0.0367 - val_loss: 0.0577 - val_mean_absolute_error: 0.0577
# Epoch 37/100
# 13/13 [==============================] - 1s 50ms/step - loss: 0.0418 - mean_absolute_error: 0.0418 - val_loss: 0.0582 - val_mean_absolute_error: 0.0582
# Epoch 38/100
# 13/13 [==============================] - 1s 52ms/step - loss: 0.0379 - mean_absolute_error: 0.0379 - val_loss: 0.0698 - val_mean_absolute_error: 0.0698
# Epoch 39/100
# 13/13 [==============================] - 1s 47ms/step - loss: 0.0384 - mean_absolute_error: 0.0384 - val_loss: 0.0581 - val_mean_absolute_error: 0.0581
# Epoch 40/100
# 13/13 [==============================] - 1s 47ms/step - loss: 0.0393 - mean_absolute_error: 0.0393 - val_loss: 0.0731 - val_mean_absolute_error: 0.0731
# Epoch 41/100
# 13/13 [==============================] - 1s 46ms/step - loss: 0.0370 - mean_absolute_error: 0.0370 - val_loss: 0.0576 - val_mean_absolute_error: 0.0576
# Epoch 42/100
# 13/13 [==============================] - 1s 48ms/step - loss: 0.0353 - mean_absolute_error: 0.0353 - val_loss: 0.0593 - val_mean_absolute_error: 0.0593
# Epoch 43/100
# 13/13 [==============================] - 1s 48ms/step - loss: 0.0379 - mean_absolute_error: 0.0379 - val_loss: 0.0614 - val_mean_absolute_error: 0.0614
# Epoch 44/100
# 13/13 [==============================] - 1s 49ms/step - loss: 0.0401 - mean_absolute_error: 0.0401 - val_loss: 0.0620 - val_mean_absolute_error: 0.0620
# Epoch 45/100
# 13/13 [==============================] - 1s 47ms/step - loss: 0.0387 - mean_absolute_error: 0.0387 - val_loss: 0.0637 - val_mean_absolute_error: 0.0637
# Epoch 46/100
# 13/13 [==============================] - 1s 52ms/step - loss: 0.0427 - mean_absolute_error: 0.0427 - val_loss: 0.0585 - val_mean_absolute_error: 0.0585
# Epoch 47/100
# 13/13 [==============================] - 1s 51ms/step - loss: 0.0347 - mean_absolute_error: 0.0347 - val_loss: 0.0653 - val_mean_absolute_error: 0.0653
# Epoch 48/100
# 13/13 [==============================] - 1s 48ms/step - loss: 0.0324 - mean_absolute_error: 0.0324 - val_loss: 0.0595 - val_mean_absolute_error: 0.0595
# Epoch 49/100
# 13/13 [==============================] - 1s 49ms/step - loss: 0.0378 - mean_absolute_error: 0.0378 - val_loss: 0.0672 - val_mean_absolute_error: 0.0672
# Epoch 50/100
# 13/13 [==============================] - 1s 48ms/step - loss: 0.0385 - mean_absolute_error: 0.0385 - val_loss: 0.0587 - val_mean_absolute_error: 0.0587
# Epoch 51/100
# 13/13 [==============================] - 1s 48ms/step - loss: 0.0400 - mean_absolute_error: 0.0400 - val_loss: 0.0565 - val_mean_absolute_error: 0.0565
# Epoch 52/100
# 13/13 [==============================] - 1s 48ms/step - loss: 0.0359 - mean_absolute_error: 0.0359 - val_loss: 0.0604 - val_mean_absolute_error: 0.0604
# Epoch 53/100
# 13/13 [==============================] - 1s 52ms/step - loss: 0.0360 - mean_absolute_error: 0.0360 - val_loss: 0.0835 - val_mean_absolute_error: 0.0835
# Epoch 54/100
# 13/13 [==============================] - 1s 46ms/step - loss: 0.0533 - mean_absolute_error: 0.0533 - val_loss: 0.0750 - val_mean_absolute_error: 0.0750
# Epoch 55/100
# 13/13 [==============================] - 1s 51ms/step - loss: 0.0442 - mean_absolute_error: 0.0442 - val_loss: 0.0893 - val_mean_absolute_error: 0.0893
# Epoch 56/100
# 13/13 [==============================] - 1s 49ms/step - loss: 0.0467 - mean_absolute_error: 0.0467 - val_loss: 0.0636 - val_mean_absolute_error: 0.0636
# Epoch 57/100
# 13/13 [==============================] - 1s 51ms/step - loss: 0.0438 - mean_absolute_error: 0.0438 - val_loss: 0.0561 - val_mean_absolute_error: 0.0561
# Epoch 58/100
# 13/13 [==============================] - 1s 50ms/step - loss: 0.0382 - mean_absolute_error: 0.0382 - val_loss: 0.0638 - val_mean_absolute_error: 0.0638
# Epoch 59/100
# 13/13 [==============================] - 1s 48ms/step - loss: 0.0354 - mean_absolute_error: 0.0354 - val_loss: 0.0662 - val_mean_absolute_error: 0.0662
# Epoch 60/100
# 13/13 [==============================] - 1s 48ms/step - loss: 0.0467 - mean_absolute_error: 0.0467 - val_loss: 0.0561 - val_mean_absolute_error: 0.0561
# Epoch 61/100
# 13/13 [==============================] - 1s 49ms/step - loss: 0.0459 - mean_absolute_error: 0.0459 - val_loss: 0.0778 - val_mean_absolute_error: 0.0778
# Epoch 62/100
# 13/13 [==============================] - 1s 49ms/step - loss: 0.0404 - mean_absolute_error: 0.0404 - val_loss: 0.0618 - val_mean_absolute_error: 0.0618
# Epoch 63/100
# 13/13 [==============================] - 1s 49ms/step - loss: 0.0386 - mean_absolute_error: 0.0386 - val_loss: 0.0628 - val_mean_absolute_error: 0.0628
# Epoch 64/100
# 13/13 [==============================] - 1s 49ms/step - loss: 0.0350 - mean_absolute_error: 0.0350 - val_loss: 0.0557 - val_mean_absolute_error: 0.0557
# Epoch 65/100
# 13/13 [==============================] - 1s 53ms/step - loss: 0.0338 - mean_absolute_error: 0.0338 - val_loss: 0.0576 - val_mean_absolute_error: 0.0576
# Epoch 66/100
# 13/13 [==============================] - 1s 51ms/step - loss: 0.0373 - mean_absolute_error: 0.0373 - val_loss: 0.0546 - val_mean_absolute_error: 0.0546
# Epoch 67/100
# 13/13 [==============================] - 1s 45ms/step - loss: 0.0390 - mean_absolute_error: 0.0390 - val_loss: 0.0552 - val_mean_absolute_error: 0.0552
# Epoch 68/100
# 13/13 [==============================] - 1s 46ms/step - loss: 0.0355 - mean_absolute_error: 0.0355 - val_loss: 0.0563 - val_mean_absolute_error: 0.0563
# Epoch 69/100
# 13/13 [==============================] - 1s 46ms/step - loss: 0.0372 - mean_absolute_error: 0.0372 - val_loss: 0.0691 - val_mean_absolute_error: 0.0691
# Epoch 70/100
# 13/13 [==============================] - 1s 52ms/step - loss: 0.0433 - mean_absolute_error: 0.0433 - val_loss: 0.0563 - val_mean_absolute_error: 0.0563
# Epoch 71/100
# 13/13 [==============================] - 1s 48ms/step - loss: 0.0369 - mean_absolute_error: 0.0369 - val_loss: 0.0549 - val_mean_absolute_error: 0.0549
# Epoch 72/100
# 13/13 [==============================] - 1s 47ms/step - loss: 0.0314 - mean_absolute_error: 0.0314 - val_loss: 0.0546 - val_mean_absolute_error: 0.0546
# Epoch 73/100
# 13/13 [==============================] - 1s 48ms/step - loss: 0.0384 - mean_absolute_error: 0.0384 - val_loss: 0.1119 - val_mean_absolute_error: 0.1119
# Epoch 74/100
# 13/13 [==============================] - 1s 47ms/step - loss: 0.0489 - mean_absolute_error: 0.0489 - val_loss: 0.0603 - val_mean_absolute_error: 0.0603
# Epoch 75/100
# 13/13 [==============================] - 1s 52ms/step - loss: 0.0365 - mean_absolute_error: 0.0365 - val_loss: 0.0592 - val_mean_absolute_error: 0.0592
# Epoch 76/100
# 13/13 [==============================] - 1s 49ms/step - loss: 0.0366 - mean_absolute_error: 0.0366 - val_loss: 0.0680 - val_mean_absolute_error: 0.0680
# Epoch 77/100
# 13/13 [==============================] - 1s 47ms/step - loss: 0.0344 - mean_absolute_error: 0.0344 - val_loss: 0.0535 - val_mean_absolute_error: 0.0535
# Epoch 78/100
# 13/13 [==============================] - 1s 50ms/step - loss: 0.0334 - mean_absolute_error: 0.0334 - val_loss: 0.0926 - val_mean_absolute_error: 0.0926
# Epoch 79/100
# 13/13 [==============================] - 1s 49ms/step - loss: 0.0424 - mean_absolute_error: 0.0424 - val_loss: 0.0580 - val_mean_absolute_error: 0.0580
# Epoch 80/100
# 13/13 [==============================] - 1s 49ms/step - loss: 0.0359 - mean_absolute_error: 0.0359 - val_loss: 0.0843 - val_mean_absolute_error: 0.0843
# Epoch 81/100
# 13/13 [==============================] - 1s 48ms/step - loss: 0.0387 - mean_absolute_error: 0.0387 - val_loss: 0.0548 - val_mean_absolute_error: 0.0548
# Epoch 82/100
# 13/13 [==============================] - 1s 47ms/step - loss: 0.0398 - mean_absolute_error: 0.0398 - val_loss: 0.0607 - val_mean_absolute_error: 0.0607
# Epoch 83/100
# 13/13 [==============================] - 1s 51ms/step - loss: 0.0351 - mean_absolute_error: 0.0351 - val_loss: 0.0676 - val_mean_absolute_error: 0.0676
# Epoch 84/100
# 13/13 [==============================] - 1s 47ms/step - loss: 0.0347 - mean_absolute_error: 0.0347 - val_loss: 0.0540 - val_mean_absolute_error: 0.0540
# Epoch 85/100
# 13/13 [==============================] - 1s 50ms/step - loss: 0.0322 - mean_absolute_error: 0.0322 - val_loss: 0.0590 - val_mean_absolute_error: 0.0590
# Epoch 86/100
# 13/13 [==============================] - 1s 46ms/step - loss: 0.0371 - mean_absolute_error: 0.0371 - val_loss: 0.0519 - val_mean_absolute_error: 0.0519
# Epoch 87/100
# 13/13 [==============================] - 1s 49ms/step - loss: 0.0312 - mean_absolute_error: 0.0312 - val_loss: 0.0620 - val_mean_absolute_error: 0.0620
# Epoch 88/100
# 13/13 [==============================] - 1s 48ms/step - loss: 0.0406 - mean_absolute_error: 0.0406 - val_loss: 0.0828 - val_mean_absolute_error: 0.0828
# Epoch 89/100
# 13/13 [==============================] - 1s 53ms/step - loss: 0.0365 - mean_absolute_error: 0.0365 - val_loss: 0.0627 - val_mean_absolute_error: 0.0627
# Epoch 90/100
# 13/13 [==============================] - 1s 49ms/step - loss: 0.0396 - mean_absolute_error: 0.0396 - val_loss: 0.0615 - val_mean_absolute_error: 0.0615
# Epoch 91/100
# 13/13 [==============================] - 1s 47ms/step - loss: 0.0353 - mean_absolute_error: 0.0353 - val_loss: 0.0510 - val_mean_absolute_error: 0.0510
# Epoch 92/100
# 13/13 [==============================] - 1s 50ms/step - loss: 0.0316 - mean_absolute_error: 0.0316 - val_loss: 0.0537 - val_mean_absolute_error: 0.0537
# Epoch 93/100
# 13/13 [==============================] - 1s 51ms/step - loss: 0.0334 - mean_absolute_error: 0.0334 - val_loss: 0.0502 - val_mean_absolute_error: 0.0502
# Epoch 94/100
# 13/13 [==============================] - 1s 48ms/step - loss: 0.0327 - mean_absolute_error: 0.0327 - val_loss: 0.0568 - val_mean_absolute_error: 0.0568
# Epoch 95/100
# 13/13 [==============================] - 1s 54ms/step - loss: 0.0345 - mean_absolute_error: 0.0345 - val_loss: 0.0521 - val_mean_absolute_error: 0.0521
# Epoch 96/100
# 13/13 [==============================] - 1s 49ms/step - loss: 0.0300 - mean_absolute_error: 0.0300 - val_loss: 0.0466 - val_mean_absolute_error: 0.0466
# Epoch 97/100
# 13/13 [==============================] - 1s 53ms/step - loss: 0.0315 - mean_absolute_error: 0.0315 - val_loss: 0.0514 - val_mean_absolute_error: 0.0514
# Epoch 98/100
# 13/13 [==============================] - 1s 50ms/step - loss: 0.0342 - mean_absolute_error: 0.0342 - val_loss: 0.0501 - val_mean_absolute_error: 0.0501
# Epoch 99/100
# 13/13 [==============================] - 1s 49ms/step - loss: 0.0302 - mean_absolute_error: 0.0302 - val_loss: 0.0568 - val_mean_absolute_error: 0.0568
# Epoch 100/100
# 13/13 [==============================] - 1s 50ms/step - loss: 0.0329 - mean_absolute_error: 0.0329 - val_loss: 0.0472 - val_mean_absolute_error: 0.0472
# 輸入變數維度 (250, 5, 1)
# 預測變數維度 (250,)
# 第Y個被預測日之前ref_day天每天正規化股價
# [[0.22457992]
#  [0.23582583]
#  [0.14585823]
#  [0.14585823]
#  [0.03339847]]
# 第Y個預測日之正規化股價
# 0.04464437795239817
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0691 - mean_absolute_error: 0.0691
# 輸入變數維度 (489, 5, 1)
# 預測變數維度 (489,)
# 第Y個被預測日之前ref_day天每天正規化股價
# [[0.09607897]
#  [0.09607897]
#  [0.05869202]
#  [0.0649233 ]
#  [0.06803894]]
# 第Y個預測日之正規化股價
# 0.07426990459181737
# WARNING:tensorflow:Layer lstm_10 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# WARNING:tensorflow:Layer lstm_11 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# WARNING:tensorflow:Layer lstm_12 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# WARNING:tensorflow:Layer lstm_13 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# WARNING:tensorflow:Layer lstm_14 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_10 (LSTM)               (None, 5, 256)            264192
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 5, 256)            0
# _________________________________________________________________
# lstm_11 (LSTM)               (None, 5, 256)            525312
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 5, 256)            0
# _________________________________________________________________
# lstm_12 (LSTM)               (None, 5, 256)            525312
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 5, 256)            0
# _________________________________________________________________
# lstm_13 (LSTM)               (None, 5, 256)            525312
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 5, 256)            0
# _________________________________________________________________
# lstm_14 (LSTM)               (None, 256)               525312
# _________________________________________________________________
# dropout_14 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 2,365,697
# Trainable params: 2,365,697
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 13/13 [==============================] - 5s 98ms/step - loss: 0.2467 - mean_absolute_error: 0.2467 - val_loss: 0.4234 - val_mean_absolute_error: 0.4234
# Epoch 2/100
# 13/13 [==============================] - 1s 50ms/step - loss: 0.1393 - mean_absolute_error: 0.1393 - val_loss: 0.2819 - val_mean_absolute_error: 0.2819
# Epoch 3/100
# 13/13 [==============================] - 1s 52ms/step - loss: 0.0875 - mean_absolute_error: 0.0875 - val_loss: 0.6145 - val_mean_absolute_error: 0.6145
# Epoch 4/100
# 13/13 [==============================] - 1s 49ms/step - loss: 0.0824 - mean_absolute_error: 0.0824 - val_loss: 0.1687 - val_mean_absolute_error: 0.1687
# Epoch 5/100
# 13/13 [==============================] - 1s 52ms/step - loss: 0.0576 - mean_absolute_error: 0.0576 - val_loss: 0.0835 - val_mean_absolute_error: 0.0835
# Epoch 6/100
# 13/13 [==============================] - 1s 52ms/step - loss: 0.0403 - mean_absolute_error: 0.0403 - val_loss: 0.0762 - val_mean_absolute_error: 0.0762
# Epoch 7/100
# 13/13 [==============================] - 1s 50ms/step - loss: 0.0418 - mean_absolute_error: 0.0418 - val_loss: 0.0774 - val_mean_absolute_error: 0.0774
# Epoch 8/100
# 13/13 [==============================] - 1s 47ms/step - loss: 0.0462 - mean_absolute_error: 0.0462 - val_loss: 0.0728 - val_mean_absolute_error: 0.0728
# Epoch 9/100
# 13/13 [==============================] - 1s 53ms/step - loss: 0.0446 - mean_absolute_error: 0.0446 - val_loss: 0.0549 - val_mean_absolute_error: 0.0549
# Epoch 10/100
# 13/13 [==============================] - 1s 54ms/step - loss: 0.0437 - mean_absolute_error: 0.0437 - val_loss: 0.0841 - val_mean_absolute_error: 0.0841
# Epoch 11/100
# 13/13 [==============================] - 1s 49ms/step - loss: 0.0467 - mean_absolute_error: 0.0467 - val_loss: 0.0822 - val_mean_absolute_error: 0.0822
# Epoch 12/100
# 13/13 [==============================] - 1s 52ms/step - loss: 0.0494 - mean_absolute_error: 0.0494 - val_loss: 0.0607 - val_mean_absolute_error: 0.0607
# Epoch 13/100
# 13/13 [==============================] - 1s 50ms/step - loss: 0.0464 - mean_absolute_error: 0.0464 - val_loss: 0.0570 - val_mean_absolute_error: 0.0570
# Epoch 14/100
# 13/13 [==============================] - 1s 47ms/step - loss: 0.0419 - mean_absolute_error: 0.0419 - val_loss: 0.0681 - val_mean_absolute_error: 0.0681
# Epoch 15/100
# 13/13 [==============================] - 1s 51ms/step - loss: 0.0391 - mean_absolute_error: 0.0391 - val_loss: 0.0592 - val_mean_absolute_error: 0.0592
# Epoch 16/100
# 13/13 [==============================] - 1s 52ms/step - loss: 0.0492 - mean_absolute_error: 0.0492 - val_loss: 0.0577 - val_mean_absolute_error: 0.0577
# Epoch 17/100
# 13/13 [==============================] - 1s 52ms/step - loss: 0.0448 - mean_absolute_error: 0.0448 - val_loss: 0.0531 - val_mean_absolute_error: 0.0531
# Epoch 18/100
# 13/13 [==============================] - 1s 49ms/step - loss: 0.0422 - mean_absolute_error: 0.0422 - val_loss: 0.0588 - val_mean_absolute_error: 0.0588
# Epoch 19/100
# 13/13 [==============================] - 1s 51ms/step - loss: 0.0439 - mean_absolute_error: 0.0439 - val_loss: 0.0526 - val_mean_absolute_error: 0.0526
# Epoch 20/100
# 13/13 [==============================] - 1s 48ms/step - loss: 0.0424 - mean_absolute_error: 0.0424 - val_loss: 0.0794 - val_mean_absolute_error: 0.0794
# Epoch 21/100
# 13/13 [==============================] - 1s 53ms/step - loss: 0.0432 - mean_absolute_error: 0.0432 - val_loss: 0.0604 - val_mean_absolute_error: 0.0604
# Epoch 22/100
# 13/13 [==============================] - 1s 50ms/step - loss: 0.0377 - mean_absolute_error: 0.0377 - val_loss: 0.0527 - val_mean_absolute_error: 0.0527
# Epoch 23/100
# 13/13 [==============================] - 1s 47ms/step - loss: 0.0381 - mean_absolute_error: 0.0381 - val_loss: 0.0678 - val_mean_absolute_error: 0.0678
# Epoch 24/100
# 13/13 [==============================] - 1s 55ms/step - loss: 0.0373 - mean_absolute_error: 0.0373 - val_loss: 0.0524 - val_mean_absolute_error: 0.0524
# Epoch 25/100
# 13/13 [==============================] - 1s 49ms/step - loss: 0.0418 - mean_absolute_error: 0.0418 - val_loss: 0.0521 - val_mean_absolute_error: 0.0521
# Epoch 26/100
# 13/13 [==============================] - 1s 54ms/step - loss: 0.0380 - mean_absolute_error: 0.0380 - val_loss: 0.0644 - val_mean_absolute_error: 0.0644
# Epoch 27/100
# 13/13 [==============================] - 1s 51ms/step - loss: 0.0424 - mean_absolute_error: 0.0424 - val_loss: 0.0906 - val_mean_absolute_error: 0.0906
# Epoch 28/100
# 13/13 [==============================] - 1s 53ms/step - loss: 0.0408 - mean_absolute_error: 0.0408 - val_loss: 0.0602 - val_mean_absolute_error: 0.0602
# Epoch 29/100
# 13/13 [==============================] - 1s 50ms/step - loss: 0.0475 - mean_absolute_error: 0.0475 - val_loss: 0.0584 - val_mean_absolute_error: 0.0584
# Epoch 30/100
# 13/13 [==============================] - 1s 48ms/step - loss: 0.0382 - mean_absolute_error: 0.0382 - val_loss: 0.0547 - val_mean_absolute_error: 0.0547
# Epoch 31/100
# 13/13 [==============================] - 1s 48ms/step - loss: 0.0379 - mean_absolute_error: 0.0379 - val_loss: 0.1039 - val_mean_absolute_error: 0.1039
# Epoch 32/100
# 13/13 [==============================] - 1s 51ms/step - loss: 0.0486 - mean_absolute_error: 0.0486 - val_loss: 0.0934 - val_mean_absolute_error: 0.0934
# Epoch 33/100
# 13/13 [==============================] - 1s 49ms/step - loss: 0.0465 - mean_absolute_error: 0.0465 - val_loss: 0.1024 - val_mean_absolute_error: 0.1024
# Epoch 34/100
# 13/13 [==============================] - 1s 49ms/step - loss: 0.0363 - mean_absolute_error: 0.0363 - val_loss: 0.0526 - val_mean_absolute_error: 0.0526
# Epoch 35/100
# 13/13 [==============================] - 1s 54ms/step - loss: 0.0407 - mean_absolute_error: 0.0407 - val_loss: 0.0893 - val_mean_absolute_error: 0.0893
# Epoch 36/100
# 13/13 [==============================] - 1s 51ms/step - loss: 0.0472 - mean_absolute_error: 0.0472 - val_loss: 0.0520 - val_mean_absolute_error: 0.0520
# Epoch 37/100
# ...
# Epoch 6/100
# 13/13 [==============================] - 1s 56ms/step - loss: 0.0857 - mean_absolute_error: 0.0857 - val_loss: 0.1358 - val_mean_absolute_error: 0.1358
# Epoch 7/100
# 13/13 [==============================] - 1s 55ms/step - loss: 0.0718 - mean_absolute_error: 0.0718 - val_loss: 0.0912 - val_mean_absolute_error: 0.0912
# Epoch 8/100
# 13/13 [==============================] - 1s 57ms/step - loss: 0.0575 - mean_absolute_error: 0.0575 - val_loss: 0.1297 - val_mean_absolute_error: 0.1297
# Epoch 9/100
# 13/13 [==============================] - 1s 55ms/step - loss: 0.0651 - mean_absolute_error: 0.0651 - val_loss: 0.0911 - val_mean_absolute_error: 0.0911
# Epoch 10/100
# 13/13 [==============================] - 1s 52ms/step - loss: 0.0580 - mean_absolute_error: 0.0580 - val_loss: 0.0819 - val_mean_absolute_error: 0.0819
# Epoch 11/100
# 13/13 [==============================] - 1s 59ms/step - loss: 0.0643 - mean_absolute_error: 0.0643 - val_loss: 0.0817 - val_mean_absolute_error: 0.0817
# Epoch 12/100
# 13/13 [==============================] - 1s 55ms/step - loss: 0.0562 - mean_absolute_error: 0.0562 - val_loss: 0.0870 - val_mean_absolute_error: 0.0870
# Epoch 13/100
# 13/13 [==============================] - 1s 55ms/step - loss: 0.0597 - mean_absolute_error: 0.0597 - val_loss: 0.0814 - val_mean_absolute_error: 0.0814
# Epoch 14/100
# 13/13 [==============================] - 1s 56ms/step - loss: 0.0637 - mean_absolute_error: 0.0637 - val_loss: 0.0829 - val_mean_absolute_error: 0.0829
# Epoch 15/100
# 13/13 [==============================] - 1s 54ms/step - loss: 0.0543 - mean_absolute_error: 0.0543 - val_loss: 0.0802 - val_mean_absolute_error: 0.0802
# Epoch 16/100
# 13/13 [==============================] - 1s 54ms/step - loss: 0.0545 - mean_absolute_error: 0.0545 - val_loss: 0.0919 - val_mean_absolute_error: 0.0919
# Epoch 17/100
# 13/13 [==============================] - 1s 56ms/step - loss: 0.0531 - mean_absolute_error: 0.0531 - val_loss: 0.0835 - val_mean_absolute_error: 0.0835
# Epoch 18/100
# 13/13 [==============================] - 1s 54ms/step - loss: 0.0564 - mean_absolute_error: 0.0564 - val_loss: 0.0883 - val_mean_absolute_error: 0.0883
# Epoch 19/100
# 13/13 [==============================] - 1s 52ms/step - loss: 0.0548 - mean_absolute_error: 0.0548 - val_loss: 0.0823 - val_mean_absolute_error: 0.0823
# Epoch 20/100
# 13/13 [==============================] - 1s 57ms/step - loss: 0.0531 - mean_absolute_error: 0.0531 - val_loss: 0.0980 - val_mean_absolute_error: 0.0980
# Epoch 21/100
# 13/13 [==============================] - 1s 60ms/step - loss: 0.0557 - mean_absolute_error: 0.0557 - val_loss: 0.0942 - val_mean_absolute_error: 0.0942
# Epoch 22/100
# 13/13 [==============================] - 1s 55ms/step - loss: 0.0531 - mean_absolute_error: 0.0531 - val_loss: 0.0831 - val_mean_absolute_error: 0.0831
# Epoch 23/100
# 13/13 [==============================] - 1s 58ms/step - loss: 0.0554 - mean_absolute_error: 0.0554 - val_loss: 0.0981 - val_mean_absolute_error: 0.0981
# Epoch 24/100
# 13/13 [==============================] - 1s 56ms/step - loss: 0.0581 - mean_absolute_error: 0.0581 - val_loss: 0.0978 - val_mean_absolute_error: 0.0978
# Epoch 25/100
# 13/13 [==============================] - 1s 54ms/step - loss: 0.0541 - mean_absolute_error: 0.0541 - val_loss: 0.0922 - val_mean_absolute_error: 0.0922
# Epoch 26/100
# 13/13 [==============================] - 1s 61ms/step - loss: 0.0526 - mean_absolute_error: 0.0526 - val_loss: 0.0872 - val_mean_absolute_error: 0.0872
# Epoch 27/100
# 13/13 [==============================] - 1s 56ms/step - loss: 0.0505 - mean_absolute_error: 0.0505 - val_loss: 0.0910 - val_mean_absolute_error: 0.0910
# Epoch 28/100
# 13/13 [==============================] - 1s 58ms/step - loss: 0.0505 - mean_absolute_error: 0.0505 - val_loss: 0.0946 - val_mean_absolute_error: 0.0946
# Epoch 29/100
# 13/13 [==============================] - 1s 55ms/step - loss: 0.0460 - mean_absolute_error: 0.0460 - val_loss: 0.1064 - val_mean_absolute_error: 0.1064
# Epoch 30/100
# 13/13 [==============================] - 1s 56ms/step - loss: 0.0509 - mean_absolute_error: 0.0509 - val_loss: 0.0867 - val_mean_absolute_error: 0.0867
# Epoch 31/100
# 13/13 [==============================] - 1s 57ms/step - loss: 0.0494 - mean_absolute_error: 0.0494 - val_loss: 0.0877 - val_mean_absolute_error: 0.0877
# Epoch 32/100
# 13/13 [==============================] - 1s 53ms/step - loss: 0.0497 - mean_absolute_error: 0.0497 - val_loss: 0.1046 - val_mean_absolute_error: 0.1046
# Epoch 33/100
# 13/13 [==============================] - 1s 55ms/step - loss: 0.0554 - mean_absolute_error: 0.0554 - val_loss: 0.1149 - val_mean_absolute_error: 0.1149
# Epoch 34/100
# 13/13 [==============================] - 1s 62ms/step - loss: 0.0552 - mean_absolute_error: 0.0552 - val_loss: 0.0985 - val_mean_absolute_error: 0.0985
# Epoch 35/100
# 13/13 [==============================] - 1s 53ms/step - loss: 0.0474 - mean_absolute_error: 0.0474 - val_loss: 0.0960 - val_mean_absolute_error: 0.0960
# Epoch 36/100
# 13/13 [==============================] - 1s 61ms/step - loss: 0.0493 - mean_absolute_error: 0.0493 - val_loss: 0.0980 - val_mean_absolute_error: 0.0980
# Epoch 37/100
# 13/13 [==============================] - 1s 57ms/step - loss: 0.0499 - mean_absolute_error: 0.0499 - val_loss: 0.1007 - val_mean_absolute_error: 0.1007
# Epoch 38/100
# 13/13 [==============================] - 1s 59ms/step - loss: 0.0489 - mean_absolute_error: 0.0489 - val_loss: 0.0976 - val_mean_absolute_error: 0.0976
# Epoch 39/100
# 13/13 [==============================] - 1s 53ms/step - loss: 0.0483 - mean_absolute_error: 0.0483 - val_loss: 0.0991 - val_mean_absolute_error: 0.0991
# Epoch 40/100
# 13/13 [==============================] - 1s 56ms/step - loss: 0.0466 - mean_absolute_error: 0.0466 - val_loss: 0.0999 - val_mean_absolute_error: 0.0999
# Epoch 41/100
# 13/13 [==============================] - 1s 55ms/step - loss: 0.0501 - mean_absolute_error: 0.0501 - val_loss: 0.0970 - val_mean_absolute_error: 0.0970
# Epoch 42/100
# 13/13 [==============================] - 1s 56ms/step - loss: 0.0476 - mean_absolute_error: 0.0476 - val_loss: 0.1008 - val_mean_absolute_error: 0.1008
# Epoch 43/100
# 13/13 [==============================] - 1s 54ms/step - loss: 0.0518 - mean_absolute_error: 0.0518 - val_loss: 0.1404 - val_mean_absolute_error: 0.1404
# Epoch 44/100
# 13/13 [==============================] - 1s 59ms/step - loss: 0.0683 - mean_absolute_error: 0.0683 - val_loss: 0.1024 - val_mean_absolute_error: 0.1024
# Epoch 45/100
# 13/13 [==============================] - 1s 56ms/step - loss: 0.0502 - mean_absolute_error: 0.0502 - val_loss: 0.1014 - val_mean_absolute_error: 0.1014
# Epoch 46/100
# 13/13 [==============================] - 1s 55ms/step - loss: 0.0515 - mean_absolute_error: 0.0515 - val_loss: 0.0988 - val_mean_absolute_error: 0.0988
# Epoch 47/100
# 13/13 [==============================] - 1s 56ms/step - loss: 0.0530 - mean_absolute_error: 0.0530 - val_loss: 0.1092 - val_mean_absolute_error: 0.1092
# Epoch 48/100
# 13/13 [==============================] - 1s 57ms/step - loss: 0.0547 - mean_absolute_error: 0.0547 - val_loss: 0.1064 - val_mean_absolute_error: 0.1064
# Epoch 49/100
# 13/13 [==============================] - 1s 61ms/step - loss: 0.0473 - mean_absolute_error: 0.0473 - val_loss: 0.0995 - val_mean_absolute_error: 0.0995
# Epoch 50/100
# 13/13 [==============================] - 1s 57ms/step - loss: 0.0549 - mean_absolute_error: 0.0549 - val_loss: 0.1096 - val_mean_absolute_error: 0.1096
# Epoch 51/100
# 13/13 [==============================] - 1s 55ms/step - loss: 0.0492 - mean_absolute_error: 0.0492 - val_loss: 0.1000 - val_mean_absolute_error: 0.1000
# Epoch 52/100
# 13/13 [==============================] - 1s 53ms/step - loss: 0.0526 - mean_absolute_error: 0.0526 - val_loss: 0.1066 - val_mean_absolute_error: 0.1066
# Epoch 53/100
# 13/13 [==============================] - 1s 54ms/step - loss: 0.0503 - mean_absolute_error: 0.0503 - val_loss: 0.1002 - val_mean_absolute_error: 0.1002
# Epoch 54/100
# 13/13 [==============================] - 1s 59ms/step - loss: 0.0445 - mean_absolute_error: 0.0445 - val_loss: 0.1056 - val_mean_absolute_error: 0.1056
# Epoch 55/100
# 13/13 [==============================] - 1s 53ms/step - loss: 0.0521 - mean_absolute_error: 0.0521 - val_loss: 0.1111 - val_mean_absolute_error: 0.1111
# Epoch 56/100
# 13/13 [==============================] - 1s 56ms/step - loss: 0.0469 - mean_absolute_error: 0.0469 - val_loss: 0.1011 - val_mean_absolute_error: 0.1011
# Epoch 57/100
# 13/13 [==============================] - 1s 53ms/step - loss: 0.0538 - mean_absolute_error: 0.0538 - val_loss: 0.0992 - val_mean_absolute_error: 0.0992
# Epoch 58/100
# 13/13 [==============================] - 1s 56ms/step - loss: 0.0444 - mean_absolute_error: 0.0444 - val_loss: 0.1125 - val_mean_absolute_error: 0.1125
# Epoch 59/100
# 13/13 [==============================] - 1s 50ms/step - loss: 0.0509 - mean_absolute_error: 0.0509 - val_loss: 0.1031 - val_mean_absolute_error: 0.1031
# Epoch 60/100
# 13/13 [==============================] - 1s 55ms/step - loss: 0.0466 - mean_absolute_error: 0.0466 - val_loss: 0.0976 - val_mean_absolute_error: 0.0976
# Epoch 61/100
# 13/13 [==============================] - 1s 50ms/step - loss: 0.0456 - mean_absolute_error: 0.0456 - val_loss: 0.1158 - val_mean_absolute_error: 0.1158
# Epoch 62/100
# 13/13 [==============================] - 1s 55ms/step - loss: 0.0451 - mean_absolute_error: 0.0451 - val_loss: 0.0974 - val_mean_absolute_error: 0.0974
# Epoch 63/100
# 13/13 [==============================] - 1s 56ms/step - loss: 0.0490 - mean_absolute_error: 0.0490 - val_loss: 0.1138 - val_mean_absolute_error: 0.1138
# Epoch 64/100
# 13/13 [==============================] - 1s 54ms/step - loss: 0.0459 - mean_absolute_error: 0.0459 - val_loss: 0.1001 - val_mean_absolute_error: 0.1001
# Epoch 65/100
# 13/13 [==============================] - 1s 51ms/step - loss: 0.0512 - mean_absolute_error: 0.0512 - val_loss: 0.1041 - val_mean_absolute_error: 0.1041
# Epoch 66/100
# 13/13 [==============================] - 1s 58ms/step - loss: 0.0478 - mean_absolute_error: 0.0478 - val_loss: 0.1114 - val_mean_absolute_error: 0.1114
# Epoch 67/100
# 13/13 [==============================] - 1s 53ms/step - loss: 0.0469 - mean_absolute_error: 0.0469 - val_loss: 0.1078 - val_mean_absolute_error: 0.1078
# Epoch 68/100
# 13/13 [==============================] - 1s 62ms/step - loss: 0.0443 - mean_absolute_error: 0.0443 - val_loss: 0.1021 - val_mean_absolute_error: 0.1021
# Epoch 69/100
# 13/13 [==============================] - 1s 56ms/step - loss: 0.0464 - mean_absolute_error: 0.0464 - val_loss: 0.1051 - val_mean_absolute_error: 0.1051
# Epoch 70/100
# 13/13 [==============================] - 1s 60ms/step - loss: 0.0502 - mean_absolute_error: 0.0502 - val_loss: 0.1010 - val_mean_absolute_error: 0.1010
# Epoch 71/100
# 13/13 [==============================] - 1s 59ms/step - loss: 0.0475 - mean_absolute_error: 0.0475 - val_loss: 0.1038 - val_mean_absolute_error: 0.1038
# Epoch 72/100
# 13/13 [==============================] - 1s 59ms/step - loss: 0.0445 - mean_absolute_error: 0.0445 - val_loss: 0.1075 - val_mean_absolute_error: 0.1075
# Epoch 73/100
# 13/13 [==============================] - 1s 56ms/step - loss: 0.0485 - mean_absolute_error: 0.0485 - val_loss: 0.1099 - val_mean_absolute_error: 0.1099
# Epoch 74/100
# 13/13 [==============================] - 1s 50ms/step - loss: 0.0483 - mean_absolute_error: 0.0483 - val_loss: 0.1072 - val_mean_absolute_error: 0.1072
# Epoch 75/100
# 13/13 [==============================] - 1s 58ms/step - loss: 0.0484 - mean_absolute_error: 0.0484 - val_loss: 0.1027 - val_mean_absolute_error: 0.1027
# Epoch 76/100
# 13/13 [==============================] - 1s 56ms/step - loss: 0.0455 - mean_absolute_error: 0.0455 - val_loss: 0.1084 - val_mean_absolute_error: 0.1084
# Epoch 77/100
# 13/13 [==============================] - 1s 59ms/step - loss: 0.0443 - mean_absolute_error: 0.0443 - val_loss: 0.1093 - val_mean_absolute_error: 0.1093
# Epoch 78/100
# 13/13 [==============================] - 1s 55ms/step - loss: 0.0484 - mean_absolute_error: 0.0484 - val_loss: 0.1030 - val_mean_absolute_error: 0.1030
# Epoch 79/100
# 13/13 [==============================] - 1s 57ms/step - loss: 0.0487 - mean_absolute_error: 0.0487 - val_loss: 0.1088 - val_mean_absolute_error: 0.1088
# Epoch 80/100
# 13/13 [==============================] - 1s 57ms/step - loss: 0.0475 - mean_absolute_error: 0.0475 - val_loss: 0.1047 - val_mean_absolute_error: 0.1047
# Epoch 81/100
# 13/13 [==============================] - 1s 60ms/step - loss: 0.0443 - mean_absolute_error: 0.0443 - val_loss: 0.1054 - val_mean_absolute_error: 0.1054
# Epoch 82/100
# 13/13 [==============================] - 1s 60ms/step - loss: 0.0484 - mean_absolute_error: 0.0484 - val_loss: 0.1148 - val_mean_absolute_error: 0.1148
# Epoch 83/100
# 13/13 [==============================] - 1s 60ms/step - loss: 0.0468 - mean_absolute_error: 0.0468 - val_loss: 0.1123 - val_mean_absolute_error: 0.1123
# Epoch 84/100
# 13/13 [==============================] - 1s 53ms/step - loss: 0.0481 - mean_absolute_error: 0.0481 - val_loss: 0.1105 - val_mean_absolute_error: 0.1105
# Epoch 85/100
# 13/13 [==============================] - 1s 56ms/step - loss: 0.0457 - mean_absolute_error: 0.0457 - val_loss: 0.1151 - val_mean_absolute_error: 0.1151
# Epoch 86/100
# 13/13 [==============================] - 1s 58ms/step - loss: 0.0485 - mean_absolute_error: 0.0485 - val_loss: 0.1143 - val_mean_absolute_error: 0.1143
# Epoch 87/100
# 13/13 [==============================] - 1s 59ms/step - loss: 0.0532 - mean_absolute_error: 0.0532 - val_loss: 0.1137 - val_mean_absolute_error: 0.1137
# Epoch 88/100
# 13/13 [==============================] - 1s 58ms/step - loss: 0.0543 - mean_absolute_error: 0.0543 - val_loss: 0.1139 - val_mean_absolute_error: 0.1139
# Epoch 89/100
# 13/13 [==============================] - 1s 59ms/step - loss: 0.0438 - mean_absolute_error: 0.0438 - val_loss: 0.1111 - val_mean_absolute_error: 0.1111
# Epoch 90/100
# 13/13 [==============================] - 1s 61ms/step - loss: 0.0436 - mean_absolute_error: 0.0436 - val_loss: 0.1051 - val_mean_absolute_error: 0.1051
# Epoch 91/100
# 13/13 [==============================] - 1s 57ms/step - loss: 0.0446 - mean_absolute_error: 0.0446 - val_loss: 0.1173 - val_mean_absolute_error: 0.1173
# Epoch 92/100
# 13/13 [==============================] - 1s 62ms/step - loss: 0.0461 - mean_absolute_error: 0.0461 - val_loss: 0.1038 - val_mean_absolute_error: 0.1038
# Epoch 93/100
# 13/13 [==============================] - 1s 53ms/step - loss: 0.0443 - mean_absolute_error: 0.0443 - val_loss: 0.1129 - val_mean_absolute_error: 0.1129
# Epoch 94/100
# 13/13 [==============================] - 1s 56ms/step - loss: 0.0444 - mean_absolute_error: 0.0444 - val_loss: 0.1098 - val_mean_absolute_error: 0.1098
# Epoch 95/100
# 13/13 [==============================] - 1s 55ms/step - loss: 0.0480 - mean_absolute_error: 0.0480 - val_loss: 0.1044 - val_mean_absolute_error: 0.1044
# Epoch 96/100
# 13/13 [==============================] - 1s 55ms/step - loss: 0.0516 - mean_absolute_error: 0.0516 - val_loss: 0.1100 - val_mean_absolute_error: 0.1100
# Epoch 97/100
# 13/13 [==============================] - 1s 56ms/step - loss: 0.0421 - mean_absolute_error: 0.0421 - val_loss: 0.1077 - val_mean_absolute_error: 0.1077
# Epoch 98/100
# 13/13 [==============================] - 1s 54ms/step - loss: 0.0478 - mean_absolute_error: 0.0478 - val_loss: 0.1082 - val_mean_absolute_error: 0.1082
# Epoch 99/100
# 13/13 [==============================] - 1s 54ms/step - loss: 0.0471 - mean_absolute_error: 0.0471 - val_loss: 0.1048 - val_mean_absolute_error: 0.1048
# Epoch 100/100
# 13/13 [==============================] - 1s 54ms/step - loss: 0.0457 - mean_absolute_error: 0.0457 - val_loss: 0.1014 - val_mean_absolute_error: 0.1014
# 輸入變數維度 (250, 5, 1)
# 預測變數維度 (250,)
# 第Y個被預測日之前ref_day天每天正規化股價
# [[0.03687996]
#  [0.        ]
#  [0.01525108]
#  [0.01788524]
#  [0.10426187]]
# 第Y個預測日之正規化股價
# 0.10564829167846657
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0841 - mean_absolute_error: 0.0841

# %%
rdf
# Out:
#            TSLA     4958.TW     2330.TW  ...  600885.SS        DAN         TEL
# 0    164.762466  113.493279  303.481903  ...  32.461266  18.048777   96.628647
# 1    165.420288  113.155228  303.601746  ...  32.198639  18.048777   96.628700
# 2    166.576660  112.605728  303.472076  ...  31.099335  18.048777   96.628769
# 3    165.946518  111.599098  303.512848  ...  30.842731  18.048777   96.628746
# 4    165.680328  109.867966  302.629883  ...  30.899660  18.048777   96.628685
# ..          ...         ...         ...  ...        ...        ...         ...
# 245  423.718689  106.409615  597.139832  ...  49.212040  24.990919  128.734970
# 246  422.383026  104.864418  596.606934  ...  49.444962  24.943350  128.270035
# 247  422.277618  104.322083  598.377991  ...  49.801472  24.985424  128.565063
# 248  419.272552  104.409607  599.212463  ...  50.049538  25.252113  129.497101
# 249  413.669464  104.507759  599.950623  ...  50.433281  25.332342  129.584229
#
# [250 rows x 10 columns]

# %%
import os
os.chdir('/content/gdrive/MyDrive/Colab Notebooks/LSTM預測結果')
print(os.getcwd() )#获取当前工作路径
timenow= time.strftime("%Y-%m-%d %H:%M:%S", time.localtime()) 
type(timenow) #str

outstr= 'result'+ timenow + '.csv'
rdf.to_csv(outstr) #相对位置，保存在getwcd()获得的路径下

outstr
# Out:
# /content/gdrive/MyDrive/Colab Notebooks/LSTM預測結果
# 'result2021-05-13 09:09:49.csv'
