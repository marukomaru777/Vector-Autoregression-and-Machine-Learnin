# %%
# 資料權限
from google.colab import drive
drive.mount('/content/gdrive/',force_remount=True)
#%cd /content/drive/My-Drive/

#匯入所需套件
import numpy as np 
import matplotlib.pyplot as plt 
import pandas as pd
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation
from keras.layers.recurrent import LSTM

# 在線GPU性能检验
# !nvidia-smi
# Out:
# Mounted at /content/gdrive/
# Wed May 12 08:58:40 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 465.19.01    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   56C    P8     9W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
#匯入資料
raw = pd.read_csv('/content/gdrive/MyDrive/Colab Notebooks/test8.csv')
raw['Date'] = pd.to_datetime(raw.Date, format = '%Y/%m/%d')

#read the data
stock = raw 
amount = len(stock) #總資料筆數
stock
# Out:
#           Date        TSLA     4958.TW  ...  600885.SS        DAN         TEL
# 0   2018-06-11   66.419998   62.356850  ...  29.904634  21.776939   91.941254
# 1   2018-06-12   68.554001   61.476101  ...  30.325052  21.423853   92.215569
# 2   2018-06-13   68.956001   62.444927  ...  29.952877  20.832191   91.884514
# 3   2018-06-14   71.543999   61.476101  ...  29.692720  20.994423   93.937096
# 4   2018-06-15   71.634003   61.476101  ...  29.118149  20.813103   93.643867
# ..         ...         ...         ...  ...        ...        ...         ...
# 746 2021-04-26  738.200012  104.000000  ...  53.840000  27.290001  135.169998
# 747 2021-04-27  704.739990  106.000000  ...  54.119999  27.670000  135.149994
# 748 2021-04-28  694.400024  104.500000  ...  55.400002  27.709999  135.919998
# 749 2021-04-29  677.000000  106.000000  ...  56.290001  26.459999  138.179993
# 750 2021-04-30  709.440002  106.000000  ...  55.919998  25.299999  134.470001
#
# [751 rows x 11 columns]

# %%
#設定資料之input variable (X) 與target variable (Y)。如以被預測日前ref_day天作為input variables，以被預測日做為target variable
def xy_set(dataset, ref_day):
    predict_day=1 #predict_day:被預測天數
    X = [[0 for i in range(ref_day)] for j in range(dataset.shape[0]-predict_day-ref_day)] #宣告輸入變數空集合
    Y = [0 for j in range(dataset.shape[0]-predict_day-ref_day)] #宣告被預測變數空集合
    for i in range(dataset.shape[0]-predict_day-ref_day):
        X[i] = dataset[i:i+ref_day,0] #前ref_day天資料
        Y[i] = dataset[i+ref_day:i+ref_day+predict_day,0] #第ref_day+1天資料
    return np.array(X),np.array(Y)

# %%
def show_train_history(train_history,train,validation):
   #train_history訓練過程；train訓練結果；validation驗證結果

      plt.plot(train_history.history[train]) #描繪訓練結果
      plt.plot(train_history.history[validation]) #描繪驗證結果
      plt.title('Train History') #圖標題
      plt.ylabel(train) #y軸標籤
      plt.xlabel('Epoch') #x軸標籤
      plt.legend(['train', 'validation'], loc='upper left') #設定訓練與驗證之圖例及位置
      plt.show()

# %%
## 預設參數
ref_day = 5 #ref_day:預測參照天數
d = 0.2
dim= stock.shape[1]#-1
# %pylab inline
#讓圖形直接顯示於jupyter note

rdf= pd.DataFrame() #用于保存所有股票的预测价格

## 
from sklearn import preprocessing #使用sklearn的preprocessing的MinMaxScaler進行正規化:(x-min)/(max-min)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
def show_test_result(Real_data,Prediciton_data):
    plt.plot(Real_data, color="red", label="Real Stock Price") #描繪測試資料真實股價
    plt.plot(Prediciton_data, color="blue", label="Predicted Stock Price") #描繪測試資料預測股價
    plt.title('Stock Prediction')
    plt.ylabel('Price') 
    plt.xlabel('Time') 
    plt.legend()
    plt.show()

# %%
stock.shape
for i in range(stock.shape[1]-1):
  n= i+1
  stock_set = stock[stock.columns[n]] 

  #分割訓練資料與測試資料
  length = len(stock[stock.Date<'2018-10-30'])-ref_day #決定分割時間點，例如以2019-03-20之前ref_day天以前之有交易記錄的資料為training set
  train = stock_set[0:length] #決定資料分割時間點，例如以2021-01-31前ref_day天起為testing set
  test = stock_set[length:]

  #使用sklearn的preprocessing的MinMaxScaler進行正規化:(x-min)/(max-min)
  #執行正規化
  train = train.values.reshape(-1,1) #執行reshape，使其shape為(資料長度,1)
  scaler= preprocessing.MinMaxScaler(feature_range=(0, 1)).fit(train)
  train_nom = scaler.transform(train) #執行正規化，使得特徵值範圍介於0~1

  X_train, Y_train = xy_set(train_nom, ref_day) #區分訓練資料之input variables與output variable
  X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1)) # 轉成三維，以便符合keras recurrent之input_shape
  Y_train = np.squeeze(Y_train)
  print('輸入變數維度',X_train.shape)
  print('預測變數維度',Y_train.shape)
  print('第Y個被預測日之前ref_day天每天正規化股價')
  print(X_train[4])
  print('第Y個預測日之正規化股價')
  print(Y_train[4])

  model = Sequential()
  model.add(LSTM(units=256, activation="relu", return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2])))
  model.add(Dropout(d))
  model.add(LSTM(units=256, activation="relu", return_sequences=True, input_shape=(X_train.shape[1], dim)))
  model.add(Dropout(d))
  model.add(LSTM(units=256, activation="relu", return_sequences=True, input_shape=(X_train.shape[1], dim)))
  model.add(Dropout(d))
  model.add(LSTM(units=256, activation="relu", return_sequences=True, input_shape=(X_train.shape[1], dim)))
  model.add(Dropout(d))
  model.add(LSTM(units=256, activation="relu", return_sequences=False, input_shape=(X_train.shape[1], dim)))
  model.add(Dropout(d))  
  model.add(Dense(units=1))
      #model.compile(optimizer='adam', loss='mse')  # rmsprop
      #model.compile(loss="mean_squared_error", optimizer="adam",metrics=['mean_squared_error']) 
      # 屬迴歸分析，通常使用Mean Squared Error或Mean Absolute Error
  model.compile(loss="mean_absolute_error", optimizer="adam",metrics=['mean_absolute_error'])
  model.summary()
  train_history =model.fit(X_train, Y_train,batch_size=32,  
                         epochs=100,verbose=1,validation_split=0.2)
  
  show_train_history(train_history,'mean_absolute_error','val_mean_absolute_error')

  #分割訓練資料與測試資料
  length = len(stock[stock.Date<'2018-10-30'])-ref_day #決定分割時間點，例如以2021-01-31之前的ref_day天以後之有交易記錄的資料為testing set
  test = stock_set[length:]
  #執行正規化
  test = test.values.reshape(-1,1) #執行reshape，使其shape為(資料長度,1)
  test_scaler= preprocessing.MinMaxScaler(feature_range=(0, 1)).fit(test)
  test_nom = test_scaler.transform(test) #執行正規化，使得特徵值範圍介於0~1

  X_test, Y_test = xy_set(test_nom, ref_day) #區分訓練資料之input variables與output variable
  X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1)) # 轉成三維，以便符合keras recurrent之input_shape
  Y_test = np.squeeze(Y_test)
  print('輸入變數維度',X_test.shape)
  print('預測變數維度',Y_test.shape)
  print('第Y個被預測日之前ref_day天每天正規化股價')
  print(X_test[4])
  print('第Y個預測日之正規化股價')
  print(Y_test[4])

  scores = model.evaluate(X_test, Y_test, verbose=1) #使用model.evaluate進行模型評估，評估後的績效指標會儲存於scores
  scores[1] #傳回測試資料的mean_absolute_error

  Y_test_predict=model.predict(X_test) #測試資料預測結果
  Y_test_predict_price = test_scaler.inverse_transform(Y_test_predict) # 將正規化預測值轉換為股票價格

  X_test_real, Y_test_real = xy_set(test, ref_day) #取得測試資料之被預測日之真實股票價格
  show_test_result(Y_test_real,Y_test_predict_price) #結果若不錯，代表可以使用此模型預測某支股票的股價

  col= stock.columns[n] 
  result= pd.DataFrame(Y_test_predict_price, columns= [col])
  rdf= pd.concat([rdf, result], axis=1)
# Out:
# 輸入變數維度 (90, 5, 1)
# 預測變數維度 (90,)
# 第Y個被預測日之前ref_day天每天正規化股價
# [[0.83412145]
#  [0.93225328]
#  [0.79055891]
#  [0.86551426]
#  [0.75149205]]
# 第Y個預測日之正規化股價
# 0.6439034631215403
# WARNING:tensorflow:Layer lstm will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# WARNING:tensorflow:Layer lstm_2 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# WARNING:tensorflow:Layer lstm_3 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# WARNING:tensorflow:Layer lstm_4 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 5, 256)            264192
# _________________________________________________________________
# dropout (Dropout)            (None, 5, 256)            0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 5, 256)            525312
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 5, 256)            0
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 5, 256)            525312
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 5, 256)            0
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 5, 256)            525312
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 5, 256)            0
# _________________________________________________________________
# lstm_4 (LSTM)                (None, 256)               525312
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 257
# =================================================================
# Total params: 2,365,697
# Trainable params: 2,365,697
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 3/3 [==============================] - 8s 501ms/step - loss: 0.5157 - mean_absolute_error: 0.5157 - val_loss: 0.1590 - val_mean_absolute_error: 0.1590
# Epoch 2/100
# 3/3 [==============================] - 0s 56ms/step - loss: 0.4832 - mean_absolute_error: 0.4832 - val_loss: 0.1252 - val_mean_absolute_error: 0.1252
# Epoch 3/100
# 3/3 [==============================] - 0s 66ms/step - loss: 0.4026 - mean_absolute_error: 0.4026 - val_loss: 0.1618 - val_mean_absolute_error: 0.1618
# Epoch 4/100
# 3/3 [==============================] - 0s 58ms/step - loss: 0.1945 - mean_absolute_error: 0.1945 - val_loss: 0.4924 - val_mean_absolute_error: 0.4924
# Epoch 5/100
# 3/3 [==============================] - 0s 57ms/step - loss: 0.2630 - mean_absolute_error: 0.2630 - val_loss: 0.3901 - val_mean_absolute_error: 0.3901
# Epoch 6/100
# 3/3 [==============================] - 0s 61ms/step - loss: 0.1614 - mean_absolute_error: 0.1614 - val_loss: 0.2171 - val_mean_absolute_error: 0.2171
# Epoch 7/100
# 3/3 [==============================] - 0s 64ms/step - loss: 0.1744 - mean_absolute_error: 0.1744 - val_loss: 0.1892 - val_mean_absolute_error: 0.1892
# Epoch 8/100
# 3/3 [==============================] - 0s 63ms/step - loss: 0.2192 - mean_absolute_error: 0.2192 - val_loss: 0.2078 - val_mean_absolute_error: 0.2078
# Epoch 9/100
# 3/3 [==============================] - 0s 54ms/step - loss: 0.1780 - mean_absolute_error: 0.1780 - val_loss: 0.2662 - val_mean_absolute_error: 0.2662
# Epoch 10/100
# 3/3 [==============================] - 0s 59ms/step - loss: 0.1578 - mean_absolute_error: 0.1578 - val_loss: 0.3585 - val_mean_absolute_error: 0.3585
# Epoch 11/100
# 3/3 [==============================] - 0s 76ms/step - loss: 0.1582 - mean_absolute_error: 0.1582 - val_loss: 0.4067 - val_mean_absolute_error: 0.4067
# Epoch 12/100
# 3/3 [==============================] - 0s 57ms/step - loss: 0.1718 - mean_absolute_error: 0.1718 - val_loss: 0.3657 - val_mean_absolute_error: 0.3657
# Epoch 13/100
# 3/3 [==============================] - 0s 61ms/step - loss: 0.1601 - mean_absolute_error: 0.1601 - val_loss: 0.2823 - val_mean_absolute_error: 0.2823
# Epoch 14/100
# 3/3 [==============================] - 0s 58ms/step - loss: 0.1499 - mean_absolute_error: 0.1499 - val_loss: 0.2455 - val_mean_absolute_error: 0.2455
# Epoch 15/100
# 3/3 [==============================] - 0s 57ms/step - loss: 0.1578 - mean_absolute_error: 0.1578 - val_loss: 0.2515 - val_mean_absolute_error: 0.2515
# Epoch 16/100
# 3/3 [==============================] - 0s 55ms/step - loss: 0.1508 - mean_absolute_error: 0.1508 - val_loss: 0.2656 - val_mean_absolute_error: 0.2656
# Epoch 17/100
# 3/3 [==============================] - 0s 58ms/step - loss: 0.1548 - mean_absolute_error: 0.1548 - val_loss: 0.2905 - val_mean_absolute_error: 0.2905
# Epoch 18/100
# 3/3 [==============================] - 0s 61ms/step - loss: 0.1599 - mean_absolute_error: 0.1599 - val_loss: 0.3035 - val_mean_absolute_error: 0.3035
# Epoch 19/100
# 3/3 [==============================] - 0s 58ms/step - loss: 0.1560 - mean_absolute_error: 0.1560 - val_loss: 0.2853 - val_mean_absolute_error: 0.2853
# Epoch 20/100
# 3/3 [==============================] - 0s 61ms/step - loss: 0.1478 - mean_absolute_error: 0.1478 - val_loss: 0.2796 - val_mean_absolute_error: 0.2796
# Epoch 21/100
# 3/3 [==============================] - 0s 54ms/step - loss: 0.1401 - mean_absolute_error: 0.1401 - val_loss: 0.2957 - val_mean_absolute_error: 0.2957
# Epoch 22/100
# 3/3 [==============================] - 0s 61ms/step - loss: 0.1414 - mean_absolute_error: 0.1414 - val_loss: 0.2803 - val_mean_absolute_error: 0.2803
# Epoch 23/100
# 3/3 [==============================] - 0s 56ms/step - loss: 0.1332 - mean_absolute_error: 0.1332 - val_loss: 0.2415 - val_mean_absolute_error: 0.2415
# Epoch 24/100
# 3/3 [==============================] - 0s 79ms/step - loss: 0.1369 - mean_absolute_error: 0.1369 - val_loss: 0.2132 - val_mean_absolute_error: 0.2132
# Epoch 25/100
# 3/3 [==============================] - 0s 57ms/step - loss: 0.1386 - mean_absolute_error: 0.1386 - val_loss: 0.2094 - val_mean_absolute_error: 0.2094
# Epoch 26/100
# 3/3 [==============================] - 0s 57ms/step - loss: 0.1257 - mean_absolute_error: 0.1257 - val_loss: 0.2488 - val_mean_absolute_error: 0.2488
# Epoch 27/100
# 3/3 [==============================] - 0s 65ms/step - loss: 0.1290 - mean_absolute_error: 0.1290 - val_loss: 0.2715 - val_mean_absolute_error: 0.2715
# Epoch 28/100
# 3/3 [==============================] - 0s 57ms/step - loss: 0.1587 - mean_absolute_error: 0.1587 - val_loss: 0.1761 - val_mean_absolute_error: 0.1761
# Epoch 29/100
# 3/3 [==============================] - 0s 56ms/step - loss: 0.1490 - mean_absolute_error: 0.1490 - val_loss: 0.1599 - val_mean_absolute_error: 0.1599
# Epoch 30/100
# 3/3 [==============================] - 0s 63ms/step - loss: 0.1598 - mean_absolute_error: 0.1598 - val_loss: 0.1853 - val_mean_absolute_error: 0.1853
# Epoch 31/100
# 3/3 [==============================] - 0s 61ms/step - loss: 0.1213 - mean_absolute_error: 0.1213 - val_loss: 0.1960 - val_mean_absolute_error: 0.1960
# Epoch 32/100
# 3/3 [==============================] - 0s 62ms/step - loss: 0.1179 - mean_absolute_error: 0.1179 - val_loss: 0.1719 - val_mean_absolute_error: 0.1719
# Epoch 33/100
# 3/3 [==============================] - 0s 63ms/step - loss: 0.1213 - mean_absolute_error: 0.1213 - val_loss: 0.1760 - val_mean_absolute_error: 0.1760
# Epoch 34/100
# 3/3 [==============================] - 0s 61ms/step - loss: 0.1238 - mean_absolute_error: 0.1238 - val_loss: 0.1989 - val_mean_absolute_error: 0.1989
# Epoch 35/100
# 3/3 [==============================] - 0s 60ms/step - loss: 0.1170 - mean_absolute_error: 0.1170 - val_loss: 0.1882 - val_mean_absolute_error: 0.1882
# Epoch 36/100
# 3/3 [==============================] - 0s 60ms/step - loss: 0.1170 - mean_absolute_error: 0.1170 - val_loss: 0.1815 - val_mean_absolute_error: 0.1815
# Epoch 37/100
# 3/3 [==============================] - 0s 58ms/step - loss: 0.1169 - mean_absolute_error: 0.1169 - val_loss: 0.1877 - val_mean_absolute_error: 0.1877
# Epoch 38/100
# 3/3 [==============================] - 0s 61ms/step - loss: 0.1104 - mean_absolute_error: 0.1104 - val_loss: 0.1964 - val_mean_absolute_error: 0.1964
# Epoch 39/100
# 3/3 [==============================] - 0s 71ms/step - loss: 0.1192 - mean_absolute_error: 0.1192 - val_loss: 0.1922 - val_mean_absolute_error: 0.1922
# Epoch 40/100
# 3/3 [==============================] - 0s 67ms/step - loss: 0.1151 - mean_absolute_error: 0.1151 - val_loss: 0.1815 - val_mean_absolute_error: 0.1815
# Epoch 41/100
# 3/3 [==============================] - 0s 58ms/step - loss: 0.1202 - mean_absolute_error: 0.1202 - val_loss: 0.1825 - val_mean_absolute_error: 0.1825
# Epoch 42/100
# 3/3 [==============================] - 0s 57ms/step - loss: 0.1124 - mean_absolute_error: 0.1124 - val_loss: 0.2055 - val_mean_absolute_error: 0.2055
# Epoch 43/100
# 3/3 [==============================] - 0s 68ms/step - loss: 0.1160 - mean_absolute_error: 0.1160 - val_loss: 0.1921 - val_mean_absolute_error: 0.1921
# Epoch 44/100
# 3/3 [==============================] - 0s 63ms/step - loss: 0.1224 - mean_absolute_error: 0.1224 - val_loss: 0.1816 - val_mean_absolute_error: 0.1816
# Epoch 45/100
# 3/3 [==============================] - 0s 62ms/step - loss: 0.1250 - mean_absolute_error: 0.1250 - val_loss: 0.2043 - val_mean_absolute_error: 0.2043
# Epoch 46/100
# 3/3 [==============================] - 0s 57ms/step - loss: 0.1219 - mean_absolute_error: 0.1219 - val_loss: 0.1979 - val_mean_absolute_error: 0.1979
# Epoch 47/100
# 3/3 [==============================] - 0s 61ms/step - loss: 0.1110 - mean_absolute_error: 0.1110 - val_loss: 0.1837 - val_mean_absolute_error: 0.1837
# Epoch 48/100
# 3/3 [==============================] - 0s 59ms/step - loss: 0.1131 - mean_absolute_error: 0.1131 - val_loss: 0.2008 - val_mean_absolute_error: 0.2008
# Epoch 49/100
# 3/3 [==============================] - 0s 60ms/step - loss: 0.1129 - mean_absolute_error: 0.1129 - val_loss: 0.2078 - val_mean_absolute_error: 0.2078
# Epoch 50/100
# 3/3 [==============================] - 0s 59ms/step - loss: 0.1065 - mean_absolute_error: 0.1065 - val_loss: 0.1878 - val_mean_absolute_error: 0.1878
# Epoch 51/100
# 3/3 [==============================] - 0s 59ms/step - loss: 0.1143 - mean_absolute_error: 0.1143 - val_loss: 0.1918 - val_mean_absolute_error: 0.1918
# Epoch 52/100
# 3/3 [==============================] - 0s 64ms/step - loss: 0.1148 - mean_absolute_error: 0.1148 - val_loss: 0.2023 - val_mean_absolute_error: 0.2023
# Epoch 53/100
# 3/3 [==============================] - 0s 61ms/step - loss: 0.1144 - mean_absolute_error: 0.1144 - val_loss: 0.1852 - val_mean_absolute_error: 0.1852
# Epoch 54/100
# 3/3 [==============================] - 0s 60ms/step - loss: 0.1124 - mean_absolute_error: 0.1124 - val_loss: 0.1750 - val_mean_absolute_error: 0.1750
# Epoch 55/100
# 3/3 [==============================] - 0s 61ms/step - loss: 0.1275 - mean_absolute_error: 0.1275 - val_loss: 0.1915 - val_mean_absolute_error: 0.1915
# Epoch 56/100
# 3/3 [==============================] - 0s 59ms/step - loss: 0.1067 - mean_absolute_error: 0.1067 - val_loss: 0.1989 - val_mean_absolute_error: 0.1989
# Epoch 57/100
# 3/3 [==============================] - 0s 63ms/step - loss: 0.1034 - mean_absolute_error: 0.1034 - val_loss: 0.2015 - val_mean_absolute_error: 0.2015
# Epoch 58/100
# 3/3 [==============================] - 0s 57ms/step - loss: 0.1139 - mean_absolute_error: 0.1139 - val_loss: 0.2024 - val_mean_absolute_error: 0.2024
# Epoch 59/100
# 3/3 [==============================] - 0s 67ms/step - loss: 0.1179 - mean_absolute_error: 0.1179 - val_loss: 0.1953 - val_mean_absolute_error: 0.1953
# Epoch 60/100
# 3/3 [==============================] - 0s 60ms/step - loss: 0.1032 - mean_absolute_error: 0.1032 - val_loss: 0.1907 - val_mean_absolute_error: 0.1907
# Epoch 61/100
# 3/3 [==============================] - 0s 60ms/step - loss: 0.1051 - mean_absolute_error: 0.1051 - val_loss: 0.1903 - val_mean_absolute_error: 0.1903
# Epoch 62/100
# 3/3 [==============================] - 0s 61ms/step - loss: 0.1018 - mean_absolute_error: 0.1018 - val_loss: 0.1889 - val_mean_absolute_error: 0.1889
# Epoch 63/100
# 3/3 [==============================] - 0s 63ms/step - loss: 0.1138 - mean_absolute_error: 0.1138 - val_loss: 0.1869 - val_mean_absolute_error: 0.1869
# Epoch 64/100
# 3/3 [==============================] - 0s 57ms/step - loss: 0.1072 - mean_absolute_error: 0.1072 - val_loss: 0.1967 - val_mean_absolute_error: 0.1967
# Epoch 65/100
# 3/3 [==============================] - 0s 67ms/step - loss: 0.1044 - mean_absolute_error: 0.1044 - val_loss: 0.1898 - val_mean_absolute_error: 0.1898
# Epoch 66/100
# 3/3 [==============================] - 0s 58ms/step - loss: 0.1108 - mean_absolute_error: 0.1108 - val_loss: 0.1882 - val_mean_absolute_error: 0.1882
# Epoch 67/100
# 3/3 [==============================] - 0s 59ms/step - loss: 0.1149 - mean_absolute_error: 0.1149 - val_loss: 0.2012 - val_mean_absolute_error: 0.2012
# Epoch 68/100
# 3/3 [==============================] - 0s 58ms/step - loss: 0.1105 - mean_absolute_error: 0.1105 - val_loss: 0.2023 - val_mean_absolute_error: 0.2023
# Epoch 69/100
# 3/3 [==============================] - 0s 69ms/step - loss: 0.1118 - mean_absolute_error: 0.1118 - val_loss: 0.1873 - val_mean_absolute_error: 0.1873
# Epoch 70/100
# 3/3 [==============================] - 0s 60ms/step - loss: 0.1115 - mean_absolute_error: 0.1115 - val_loss: 0.1869 - val_mean_absolute_error: 0.1869
# Epoch 71/100
# 3/3 [==============================] - 0s 66ms/step - loss: 0.1045 - mean_absolute_error: 0.1045 - val_loss: 0.1927 - val_mean_absolute_error: 0.1927
# Epoch 72/100
# 3/3 [==============================] - 0s 57ms/step - loss: 0.1154 - mean_absolute_error: 0.1154 - val_loss: 0.1838 - val_mean_absolute_error: 0.1838
# Epoch 73/100
# 3/3 [==============================] - 0s 62ms/step - loss: 0.1039 - mean_absolute_error: 0.1039 - val_loss: 0.1772 - val_mean_absolute_error: 0.1772
# Epoch 74/100
# 3/3 [==============================] - 0s 56ms/step - loss: 0.1172 - mean_absolute_error: 0.1172 - val_loss: 0.1794 - val_mean_absolute_error: 0.1794
# Epoch 75/100
# 3/3 [==============================] - 0s 58ms/step - loss: 0.1138 - mean_absolute_error: 0.1138 - val_loss: 0.1859 - val_mean_absolute_error: 0.1859
# Epoch 76/100
# 3/3 [==============================] - 0s 63ms/step - loss: 0.1085 - mean_absolute_error: 0.1085 - val_loss: 0.1794 - val_mean_absolute_error: 0.1794
# Epoch 77/100
# 3/3 [==============================] - 0s 59ms/step - loss: 0.1095 - mean_absolute_error: 0.1095 - val_loss: 0.1842 - val_mean_absolute_error: 0.1842
# Epoch 78/100
# 3/3 [==============================] - 0s 60ms/step - loss: 0.1016 - mean_absolute_error: 0.1016 - val_loss: 0.2034 - val_mean_absolute_error: 0.2034
# Epoch 79/100
# 3/3 [==============================] - 0s 57ms/step - loss: 0.1127 - mean_absolute_error: 0.1127 - val_loss: 0.2043 - val_mean_absolute_error: 0.2043
# Epoch 80/100
# 3/3 [==============================] - 0s 62ms/step - loss: 0.1139 - mean_absolute_error: 0.1139 - val_loss: 0.1934 - val_mean_absolute_error: 0.1934
# Epoch 81/100
# 3/3 [==============================] - 0s 67ms/step - loss: 0.1077 - mean_absolute_error: 0.1077 - val_loss: 0.1985 - val_mean_absolute_error: 0.1985
# Epoch 82/100
# 3/3 [==============================] - 0s 59ms/step - loss: 0.1139 - mean_absolute_error: 0.1139 - val_loss: 0.2019 - val_mean_absolute_error: 0.2019
# Epoch 83/100
# 3/3 [==============================] - 0s 61ms/step - loss: 0.1125 - mean_absolute_error: 0.1125 - val_loss: 0.1822 - val_mean_absolute_error: 0.1822
# Epoch 84/100
# 3/3 [==============================] - 0s 59ms/step - loss: 0.1045 - mean_absolute_error: 0.1045 - val_loss: 0.1709 - val_mean_absolute_error: 0.1709
# Epoch 85/100
# 3/3 [==============================] - 0s 64ms/step - loss: 0.1189 - mean_absolute_error: 0.1189 - val_loss: 0.1795 - val_mean_absolute_error: 0.1795
# Epoch 86/100
# 3/3 [==============================] - 0s 58ms/step - loss: 0.1108 - mean_absolute_error: 0.1108 - val_loss: 0.1933 - val_mean_absolute_error: 0.1933
# Epoch 87/100
# 3/3 [==============================] - 0s 63ms/step - loss: 0.1163 - mean_absolute_error: 0.1163 - val_loss: 0.1771 - val_mean_absolute_error: 0.1771
# Epoch 88/100
# 3/3 [==============================] - 0s 75ms/step - loss: 0.1093 - mean_absolute_error: 0.1093 - val_loss: 0.1686 - val_mean_absolute_error: 0.1686
# Epoch 89/100
# 3/3 [==============================] - 0s 74ms/step - loss: 0.1250 - mean_absolute_error: 0.1250 - val_loss: 0.1746 - val_mean_absolute_error: 0.1746
# Epoch 90/100
# 3/3 [==============================] - 0s 61ms/step - loss: 0.1067 - mean_absolute_error: 0.1067 - val_loss: 0.1972 - val_mean_absolute_error: 0.1972
# Epoch 91/100
# 3/3 [==============================] - 0s 58ms/step - loss: 0.1134 - mean_absolute_error: 0.1134 - val_loss: 0.1851 - val_mean_absolute_error: 0.1851
# Epoch 92/100
# 3/3 [==============================] - 0s 61ms/step - loss: 0.1062 - mean_absolute_error: 0.1062 - val_loss: 0.1711 - val_mean_absolute_error: 0.1711
# Epoch 93/100
# 3/3 [==============================] - 0s 57ms/step - loss: 0.1191 - mean_absolute_error: 0.1191 - val_loss: 0.1860 - val_mean_absolute_error: 0.1860
# Epoch 94/100
# 3/3 [==============================] - 0s 64ms/step - loss: 0.1039 - mean_absolute_error: 0.1039 - val_loss: 0.1936 - val_mean_absolute_error: 0.1936
# Epoch 95/100
# 3/3 [==============================] - 0s 63ms/step - loss: 0.1098 - mean_absolute_error: 0.1098 - val_loss: 0.1871 - val_mean_absolute_error: 0.1871
# Epoch 96/100
# 3/3 [==============================] - 0s 59ms/step - loss: 0.1069 - mean_absolute_error: 0.1069 - val_loss: 0.1953 - val_mean_absolute_error: 0.1953
# Epoch 97/100
# 3/3 [==============================] - 0s 62ms/step - loss: 0.1059 - mean_absolute_error: 0.1059 - val_loss: 0.1998 - val_mean_absolute_error: 0.1998
# Epoch 98/100
# 3/3 [==============================] - 0s 65ms/step - loss: 0.1175 - mean_absolute_error: 0.1175 - val_loss: 0.1983 - val_mean_absolute_error: 0.1983
# Epoch 99/100
# 3/3 [==============================] - 0s 65ms/step - loss: 0.1136 - mean_absolute_error: 0.1136 - val_loss: 0.1826 - val_mean_absolute_error: 0.1826
# Epoch 100/100
# 3/3 [==============================] - 0s 64ms/step - loss: 0.1073 - mean_absolute_error: 0.1073 - val_loss: 0.1785 - val_mean_absolute_error: 0.1785
# 輸入變數維度 (649, 5, 1)
# 預測變數維度 (649,)
# 第Y個被預測日之前ref_day天每天正規化股價
# [[0.0367947 ]
#  [0.03562628]
#  [0.03737773]
#  [0.03902061]
#  [0.03952338]]
# 第Y個預測日之正規化股價
# 0.03834079115472325
# 21/21 [==============================] - 0s 5ms/step - loss: 0.1847 - mean_absolute_error: 0.1847
# 輸入變數維度 (90, 5, 1)
# 預測變數維度 (90,)
# 第Y個被預測日之前ref_day天每天正規化股價
# [[0.26340847]
#  [0.26340847]
#  [0.20175957]
#  [0.14011068]
#  [0.22417757]]
# 第Y個預測日之正規化股價
# 0.15692405833913492
# WARNING:tensorflow:Layer lstm_5 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# WARNING:tensorflow:Layer lstm_6 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# WARNING:tensorflow:Layer lstm_7 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# WARNING:tensorflow:Layer lstm_8 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# WARNING:tensorflow:Layer lstm_9 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_5 (LSTM)                (None, 5, 256)            264192
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 5, 256)            0
# _________________________________________________________________
# lstm_6 (LSTM)                (None, 5, 256)            525312
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 5, 256)            0
# _________________________________________________________________
# lstm_7 (LSTM)                (None, 5, 256)            525312
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 5, 256)            0
# _________________________________________________________________
# lstm_8 (LSTM)                (None, 5, 256)            525312
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 5, 256)            0
# _________________________________________________________________
# lstm_9 (LSTM)                (None, 256)               525312
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 2,365,697
# Trainable params: 2,365,697
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 3/3 [==============================] - 5s 336ms/step - loss: 0.5028 - mean_absolute_error: 0.5028 - val_loss: 0.2956 - val_mean_absolute_error: 0.2956
# Epoch 2/100
# 3/3 [==============================] - 0s 58ms/step - loss: 0.4894 - mean_absolute_error: 0.4894 - val_loss: 0.2316 - val_mean_absolute_error: 0.2316
# Epoch 3/100
# 3/3 [==============================] - 0s 58ms/step - loss: 0.4021 - mean_absolute_error: 0.4021 - val_loss: 0.1012 - val_mean_absolute_error: 0.1012
# Epoch 4/100
# 3/3 [==============================] - 0s 74ms/step - loss: 0.3231 - mean_absolute_error: 0.3231 - val_loss: 0.3271 - val_mean_absolute_error: 0.3271
# Epoch 5/100
# 3/3 [==============================] - 0s 71ms/step - loss: 0.2659 - mean_absolute_error: 0.2659 - val_loss: 0.2746 - val_mean_absolute_error: 0.2746
# Epoch 6/100
# 3/3 [==============================] - 0s 60ms/step - loss: 0.2415 - mean_absolute_error: 0.2415 - val_loss: 0.1388 - val_mean_absolute_error: 0.1388
# Epoch 7/100
# 3/3 [==============================] - 0s 62ms/step - loss: 0.2476 - mean_absolute_error: 0.2476 - val_loss: 0.1410 - val_mean_absolute_error: 0.1410
# Epoch 8/100
# 3/3 [==============================] - 0s 64ms/step - loss: 0.2413 - mean_absolute_error: 0.2413 - val_loss: 0.2257 - val_mean_absolute_error: 0.2257
# Epoch 9/100
# 3/3 [==============================] - 0s 67ms/step - loss: 0.2083 - mean_absolute_error: 0.2083 - val_loss: 0.2412 - val_mean_absolute_error: 0.2412
# Epoch 10/100
# 3/3 [==============================] - 0s 60ms/step - loss: 0.1959 - mean_absolute_error: 0.1959 - val_loss: 0.1338 - val_mean_absolute_error: 0.1338
# Epoch 11/100
# 3/3 [==============================] - 0s 63ms/step - loss: 0.1935 - mean_absolute_error: 0.1935 - val_loss: 0.1083 - val_mean_absolute_error: 0.1083
# Epoch 12/100
# 3/3 [==============================] - 0s 59ms/step - loss: 0.1658 - mean_absolute_error: 0.1658 - val_loss: 0.1347 - val_mean_absolute_error: 0.1347
# Epoch 13/100
# 3/3 [==============================] - 0s 58ms/step - loss: 0.1649 - mean_absolute_error: 0.1649 - val_loss: 0.0978 - val_mean_absolute_error: 0.0978
# Epoch 14/100
# 3/3 [==============================] - 0s 61ms/step - loss: 0.1741 - mean_absolute_error: 0.1741 - val_loss: 0.1210 - val_mean_absolute_error: 0.1210
# Epoch 15/100
# 3/3 [==============================] - 0s 57ms/step - loss: 0.1939 - mean_absolute_error: 0.1939 - val_loss: 0.0959 - val_mean_absolute_error: 0.0959
# Epoch 16/100
# 3/3 [==============================] - 0s 67ms/step - loss: 0.1597 - mean_absolute_error: 0.1597 - val_loss: 0.0965 - val_mean_absolute_error: 0.0965
# Epoch 17/100
# 3/3 [==============================] - 0s 67ms/step - loss: 0.1350 - mean_absolute_error: 0.1350 - val_loss: 0.1070 - val_mean_absolute_error: 0.1070
# Epoch 18/100
# 3/3 [==============================] - 0s 64ms/step - loss: 0.1644 - mean_absolute_error: 0.1644 - val_loss: 0.0979 - val_mean_absolute_error: 0.0979
# Epoch 19/100
# 3/3 [==============================] - 0s 62ms/step - loss: 0.1403 - mean_absolute_error: 0.1403 - val_loss: 0.0988 - val_mean_absolute_error: 0.0988
# Epoch 20/100
# 3/3 [==============================] - 0s 61ms/step - loss: 0.1358 - mean_absolute_error: 0.1358 - val_loss: 0.1051 - val_mean_absolute_error: 0.1051
# Epoch 21/100
# 3/3 [==============================] - 0s 67ms/step - loss: 0.1433 - mean_absolute_error: 0.1433 - val_loss: 0.1058 - val_mean_absolute_error: 0.1058
# Epoch 22/100
# 3/3 [==============================] - 0s 65ms/step - loss: 0.1365 - mean_absolute_error: 0.1365 - val_loss: 0.0995 - val_mean_absolute_error: 0.0995
# Epoch 23/100
# 3/3 [==============================] - 0s 68ms/step - loss: 0.1534 - mean_absolute_error: 0.1534 - val_loss: 0.1015 - val_mean_absolute_error: 0.1015
# Epoch 24/100
# 3/3 [==============================] - 0s 66ms/step - loss: 0.1366 - mean_absolute_error: 0.1366 - val_loss: 0.1150 - val_mean_absolute_error: 0.1150
# Epoch 25/100
# 3/3 [==============================] - 0s 75ms/step - loss: 0.1197 - mean_absolute_error: 0.1197 - val_loss: 0.1056 - val_mean_absolute_error: 0.1056
# Epoch 26/100
# 3/3 [==============================] - 0s 64ms/step - loss: 0.1251 - mean_absolute_error: 0.1251 - val_loss: 0.1110 - val_mean_absolute_error: 0.1110
# Epoch 27/100
# 3/3 [==============================] - 0s 65ms/step - loss: 0.1308 - mean_absolute_error: 0.1308 - val_loss: 0.1216 - val_mean_absolute_error: 0.1216
# Epoch 28/100
# 3/3 [==============================] - 0s 60ms/step - loss: 0.1244 - mean_absolute_error: 0.1244 - val_loss: 0.1116 - val_mean_absolute_error: 0.1116
# Epoch 29/100
# 3/3 [==============================] - 0s 64ms/step - loss: 0.1114 - mean_absolute_error: 0.1114 - val_loss: 0.1174 - val_mean_absolute_error: 0.1174
# Epoch 30/100
# 3/3 [==============================] - 0s 57ms/step - loss: 0.1131 - mean_absolute_error: 0.1131 - val_loss: 0.1322 - val_mean_absolute_error: 0.1322
# Epoch 31/100
# 3/3 [==============================] - 0s 59ms/step - loss: 0.1223 - mean_absolute_error: 0.1223 - val_loss: 0.1100 - val_mean_absolute_error: 0.1100
# Epoch 32/100
# 3/3 [==============================] - 0s 73ms/step - loss: 0.1252 - mean_absolute_error: 0.1252 - val_loss: 0.1287 - val_mean_absolute_error: 0.1287
# Epoch 33/100
# 3/3 [==============================] - 0s 73ms/step - loss: 0.1471 - mean_absolute_error: 0.1471 - val_loss: 0.1028 - val_mean_absolute_error: 0.1028
# Epoch 34/100
# 3/3 [==============================] - 0s 63ms/step - loss: 0.1238 - mean_absolute_error: 0.1238 - val_loss: 0.1135 - val_mean_absolute_error: 0.1135
# Epoch 35/100
# 3/3 [==============================] - 0s 79ms/step - loss: 0.1216 - mean_absolute_error: 0.1216 - val_loss: 0.1082 - val_mean_absolute_error: 0.1082
# Epoch 36/100
# 3/3 [==============================] - 0s 72ms/step - loss: 0.1127 - mean_absolute_error: 0.1127 - val_loss: 0.1099 - val_mean_absolute_error: 0.1099
# Epoch 37/100
# 3/3 [==============================] - 0s 70ms/step - loss: 0.1083 - mean_absolute_error: 0.1083 - val_loss: 0.1420 - val_mean_absolute_error: 0.1420
# Epoch 38/100
# 3/3 [==============================] - 0s 68ms/step - loss: 0.1218 - mean_absolute_error: 0.1218 - val_loss: 0.1432 - val_mean_absolute_error: 0.1432
# Epoch 39/100
# 3/3 [==============================] - 0s 68ms/step - loss: 0.1212 - mean_absolute_error: 0.1212 - val_loss: 0.1093 - val_mean_absolute_error: 0.1093
# Epoch 40/100
# 3/3 [==============================] - 0s 60ms/step - loss: 0.1366 - mean_absolute_error: 0.1366 - val_loss: 0.1123 - val_mean_absolute_error: 0.1123
# Epoch 41/100
# 3/3 [==============================] - 0s 61ms/step - loss: 0.1174 - mean_absolute_error: 0.1174 - val_loss: 0.1297 - val_mean_absolute_error: 0.1297
# Epoch 42/100
# 3/3 [==============================] - 0s 64ms/step - loss: 0.1241 - mean_absolute_error: 0.1241 - val_loss: 0.1167 - val_mean_absolute_error: 0.1167
# Epoch 43/100
# 3/3 [==============================] - 0s 67ms/step - loss: 0.1244 - mean_absolute_error: 0.1244 - val_loss: 0.1143 - val_mean_absolute_error: 0.1143
# Epoch 44/100
# 3/3 [==============================] - 0s 75ms/step - loss: 0.1119 - mean_absolute_error: 0.1119 - val_loss: 0.1179 - val_mean_absolute_error: 0.1179
# Epoch 45/100
# 3/3 [==============================] - 0s 65ms/step - loss: 0.1124 - mean_absolute_error: 0.1124 - val_loss: 0.1116 - val_mean_absolute_error: 0.1116
# Epoch 46/100
# 3/3 [==============================] - 0s 60ms/step - loss: 0.1092 - mean_absolute_error: 0.1092 - val_loss: 0.1114 - val_mean_absolute_error: 0.1114
# Epoch 47/100
# 3/3 [==============================] - 0s 63ms/step - loss: 0.1065 - mean_absolute_error: 0.1065 - val_loss: 0.1210 - val_mean_absolute_error: 0.1210
# Epoch 48/100
# 3/3 [==============================] - 0s 78ms/step - loss: 0.1205 - mean_absolute_error: 0.1205 - val_loss: 0.1115 - val_mean_absolute_error: 0.1115
# Epoch 49/100
# 3/3 [==============================] - 0s 63ms/step - loss: 0.1152 - mean_absolute_error: 0.1152 - val_loss: 0.1166 - val_mean_absolute_error: 0.1166
# Epoch 50/100
# 3/3 [==============================] - 0s 79ms/step - loss: 0.1143 - mean_absolute_error: 0.1143 - val_loss: 0.1184 - val_mean_absolute_error: 0.1184
# Epoch 51/100
# 3/3 [==============================] - 0s 69ms/step - loss: 0.1183 - mean_absolute_error: 0.1183 - val_loss: 0.1135 - val_mean_absolute_error: 0.1135
# Epoch 52/100
# 3/3 [==============================] - 0s 63ms/step - loss: 0.1077 - mean_absolute_error: 0.1077 - val_loss: 0.1288 - val_mean_absolute_error: 0.1288
# Epoch 53/100
# 3/3 [==============================] - 0s 62ms/step - loss: 0.1164 - mean_absolute_error: 0.1164 - val_loss: 0.1344 - val_mean_absolute_error: 0.1344
# Epoch 54/100
# 3/3 [==============================] - 0s 63ms/step - loss: 0.1191 - mean_absolute_error: 0.1191 - val_loss: 0.1141 - val_mean_absolute_error: 0.1141
# Epoch 55/100
# 3/3 [==============================] - 0s 68ms/step - loss: 0.1145 - mean_absolute_error: 0.1145 - val_loss: 0.1070 - val_mean_absolute_error: 0.1070
# Epoch 56/100
# 3/3 [==============================] - 0s 61ms/step - loss: 0.1207 - mean_absolute_error: 0.1207 - val_loss: 0.1227 - val_mean_absolute_error: 0.1227
# Epoch 57/100
# 3/3 [==============================] - 0s 63ms/step - loss: 0.1104 - mean_absolute_error: 0.1104 - val_loss: 0.1183 - val_mean_absolute_error: 0.1183
# Epoch 58/100
# 3/3 [==============================] - 0s 60ms/step - loss: 0.1147 - mean_absolute_error: 0.1147 - val_loss: 0.1196 - val_mean_absolute_error: 0.1196
# Epoch 59/100
# 3/3 [==============================] - 0s 63ms/step - loss: 0.1077 - mean_absolute_error: 0.1077 - val_loss: 0.1320 - val_mean_absolute_error: 0.1320
# Epoch 60/100
# 3/3 [==============================] - 0s 60ms/step - loss: 0.1216 - mean_absolute_error: 0.1216 - val_loss: 0.1165 - val_mean_absolute_error: 0.1165
# Epoch 61/100
# 3/3 [==============================] - 0s 79ms/step - loss: 0.1129 - mean_absolute_error: 0.1129 - val_loss: 0.1089 - val_mean_absolute_error: 0.1089
# Epoch 62/100
# 3/3 [==============================] - 0s 59ms/step - loss: 0.1187 - mean_absolute_error: 0.1187 - val_loss: 0.1292 - val_mean_absolute_error: 0.1292
# Epoch 63/100
# 3/3 [==============================] - 0s 59ms/step - loss: 0.1100 - mean_absolute_error: 0.1100 - val_loss: 0.1226 - val_mean_absolute_error: 0.1226
# Epoch 64/100
# 3/3 [==============================] - 0s 59ms/step - loss: 0.1175 - mean_absolute_error: 0.1175 - val_loss: 0.1141 - val_mean_absolute_error: 0.1141
# Epoch 65/100
# 3/3 [==============================] - 0s 63ms/step - loss: 0.1100 - mean_absolute_error: 0.1100 - val_loss: 0.1195 - val_mean_absolute_error: 0.1195
# Epoch 66/100
# 3/3 [==============================] - 0s 64ms/step - loss: 0.1195 - mean_absolute_error: 0.1195 - val_loss: 0.1179 - val_mean_absolute_error: 0.1179
# Epoch 67/100
# 3/3 [==============================] - 0s 63ms/step - loss: 0.1085 - mean_absolute_error: 0.1085 - val_loss: 0.1111 - val_mean_absolute_error: 0.1111
# Epoch 68/100
# 3/3 [==============================] - 0s 64ms/step - loss: 0.1111 - mean_absolute_error: 0.1111 - val_loss: 0.1192 - val_mean_absolute_error: 0.1192
# Epoch 69/100
# 3/3 [==============================] - 0s 58ms/step - loss: 0.1135 - mean_absolute_error: 0.1135 - val_loss: 0.1181 - val_mean_absolute_error: 0.1181
# Epoch 70/100
# 3/3 [==============================] - 0s 65ms/step - loss: 0.1027 - mean_absolute_error: 0.1027 - val_loss: 0.1196 - val_mean_absolute_error: 0.1196
# Epoch 71/100
# 3/3 [==============================] - 0s 66ms/step - loss: 0.1035 - mean_absolute_error: 0.1035 - val_loss: 0.1154 - val_mean_absolute_error: 0.1154
# Epoch 72/100
# 3/3 [==============================] - 0s 59ms/step - loss: 0.1102 - mean_absolute_error: 0.1102 - val_loss: 0.1076 - val_mean_absolute_error: 0.1076
# Epoch 73/100
# 3/3 [==============================] - 0s 61ms/step - loss: 0.1153 - mean_absolute_error: 0.1153 - val_loss: 0.1246 - val_mean_absolute_error: 0.1246
# Epoch 74/100
# 3/3 [==============================] - 0s 70ms/step - loss: 0.1244 - mean_absolute_error: 0.1244 - val_loss: 0.1253 - val_mean_absolute_error: 0.1253
# Epoch 75/100
# 3/3 [==============================] - 0s 58ms/step - loss: 0.1177 - mean_absolute_error: 0.1177 - val_loss: 0.1071 - val_mean_absolute_error: 0.1071
# Epoch 76/100
# 3/3 [==============================] - 0s 60ms/step - loss: 0.1149 - mean_absolute_error: 0.1149 - val_loss: 0.1166 - val_mean_absolute_error: 0.1166
# Epoch 77/100
# 3/3 [==============================] - 0s 65ms/step - loss: 0.1050 - mean_absolute_error: 0.1050 - val_loss: 0.1271 - val_mean_absolute_error: 0.1271
# Epoch 78/100
# 3/3 [==============================] - 0s 59ms/step - loss: 0.1124 - mean_absolute_error: 0.1124 - val_loss: 0.1076 - val_mean_absolute_error: 0.1076
# Epoch 79/100
# 3/3 [==============================] - 0s 65ms/step - loss: 0.1139 - mean_absolute_error: 0.1139 - val_loss: 0.1091 - val_mean_absolute_error: 0.1091
# Epoch 80/100
# 3/3 [==============================] - 0s 61ms/step - loss: 0.1064 - mean_absolute_error: 0.1064 - val_loss: 0.1217 - val_mean_absolute_error: 0.1217
# Epoch 81/100
# 3/3 [==============================] - 0s 56ms/step - loss: 0.1041 - mean_absolute_error: 0.1041 - val_loss: 0.1258 - val_mean_absolute_error: 0.1258
# Epoch 82/100
# 3/3 [==============================] - 0s 59ms/step - loss: 0.1190 - mean_absolute_error: 0.1190 - val_loss: 0.1105 - val_mean_absolute_error: 0.1105
# Epoch 83/100
# 3/3 [==============================] - 0s 66ms/step - loss: 0.1199 - mean_absolute_error: 0.1199 - val_loss: 0.1250 - val_mean_absolute_error: 0.1250
# Epoch 84/100
# 3/3 [==============================] - 0s 62ms/step - loss: 0.1066 - mean_absolute_error: 0.1066 - val_loss: 0.1249 - val_mean_absolute_error: 0.1249
# Epoch 85/100
# 3/3 [==============================] - 0s 66ms/step - loss: 0.1051 - mean_absolute_error: 0.1051 - val_loss: 0.1088 - val_mean_absolute_error: 0.1088
# Epoch 86/100
# 3/3 [==============================] - 0s 69ms/step - loss: 0.1143 - mean_absolute_error: 0.1143 - val_loss: 0.1177 - val_mean_absolute_error: 0.1177
# Epoch 87/100
# 3/3 [==============================] - 0s 63ms/step - loss: 0.1131 - mean_absolute_error: 0.1131 - val_loss: 0.1344 - val_mean_absolute_error: 0.1344
# Epoch 88/100
# 3/3 [==============================] - 0s 61ms/step - loss: 0.1232 - mean_absolute_error: 0.1232 - val_loss: 0.1194 - val_mean_absolute_error: 0.1194
# Epoch 89/100
# 3/3 [==============================] - 0s 62ms/step - loss: 0.1019 - mean_absolute_error: 0.1019 - val_loss: 0.1110 - val_mean_absolute_error: 0.1110
# Epoch 90/100
# 3/3 [==============================] - 0s 58ms/step - loss: 0.1013 - mean_absolute_error: 0.1013 - val_loss: 0.1264 - val_mean_absolute_error: 0.1264
# Epoch 91/100
# 3/3 [==============================] - 0s 70ms/step - loss: 0.1098 - mean_absolute_error: 0.1098 - val_loss: 0.1305 - val_mean_absolute_error: 0.1305
# Epoch 92/100
# 3/3 [==============================] - 0s 74ms/step - loss: 0.1003 - mean_absolute_error: 0.1003 - val_loss: 0.1277 - val_mean_absolute_error: 0.1277
# Epoch 93/100
# 3/3 [==============================] - 0s 71ms/step - loss: 0.1081 - mean_absolute_error: 0.1081 - val_loss: 0.1266 - val_mean_absolute_error: 0.1266
# Epoch 94/100
# 3/3 [==============================] - 0s 69ms/step - loss: 0.0996 - mean_absolute_error: 0.0996 - val_loss: 0.1119 - val_mean_absolute_error: 0.1119
# Epoch 95/100
# 3/3 [==============================] - 0s 64ms/step - loss: 0.1097 - mean_absolute_error: 0.1097 - val_loss: 0.1122 - val_mean_absolute_error: 0.1122
# Epoch 96/100
# 3/3 [==============================] - 0s 58ms/step - loss: 0.0999 - mean_absolute_error: 0.0999 - val_loss: 0.1098 - val_mean_absolute_error: 0.1098
# Epoch 97/100
# 3/3 [==============================] - 0s 73ms/step - loss: 0.0978 - mean_absolute_error: 0.0978 - val_loss: 0.1086 - val_mean_absolute_error: 0.1086
# Epoch 98/100
# 3/3 [==============================] - 0s 71ms/step - loss: 0.1110 - mean_absolute_error: 0.1110 - val_loss: 0.1087 - val_mean_absolute_error: 0.1087
# Epoch 99/100
# 3/3 [==============================] - 0s 59ms/step - loss: 0.1147 - mean_absolute_error: 0.1147 - val_loss: 0.1081 - val_mean_absolute_error: 0.1081
# Epoch 100/100
# 3/3 [==============================] - 0s 65ms/step - loss: 0.0943 - mean_absolute_error: 0.0943 - val_loss: 0.1120 - val_mean_absolute_error: 0.1120
# 輸入變數維度 (649, 5, 1)
# 預測變數維度 (649,)
# 第Y個被預測日之前ref_day天每天正規化股價
# [[0.02274679]
#  [0.02166358]
#  [0.03466175]
#  [0.05849167]
#  [0.03899441]]
# 第Y個預測日之正規化股價
# 0.00974858112023913
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0903 - mean_absolute_error: 0.0903
# 輸入變數維度 (90, 5, 1)
# 預測變數維度 (90,)
# 第Y個被預測日之前ref_day天每天正規化股價
# [[0.20522495]
#  [0.20522495]
#  [0.09599821]
#  [0.11420303]
#  [0.12330544]]
# 第Y個預測日之正規化股價
# 0.1415093221998176
# WARNING:tensorflow:Layer lstm_10 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# WARNING:tensorflow:Layer lstm_11 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# WARNING:tensorflow:Layer lstm_12 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# WARNING:tensorflow:Layer lstm_13 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# WARNING:tensorflow:Layer lstm_14 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_10 (LSTM)               (None, 5, 256)            264192
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 5, 256)            0
# _________________________________________________________________
# lstm_11 (LSTM)               (None, 5, 256)            525312
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 5, 256)            0
# _________________________________________________________________
# lstm_12 (LSTM)               (None, 5, 256)            525312
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 5, 256)            0
# _________________________________________________________________
# lstm_13 (LSTM)               (None, 5, 256)            525312
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 5, 256)            0
# _________________________________________________________________
# lstm_14 (LSTM)               (None, 256)               525312
# _________________________________________________________________
# dropout_14 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 2,365,697
# Trainable params: 2,365,697
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 3/3 [==============================] - 5s 350ms/step - loss: 0.5270 - mean_absolute_error: 0.5270 - val_loss: 0.6254 - val_mean_absolute_error: 0.6254
# Epoch 2/100
# 3/3 [==============================] - 0s 67ms/step - loss: 0.4918 - mean_absolute_error: 0.4918 - val_loss: 0.5427 - val_mean_absolute_error: 0.5427
# Epoch 3/100
# 3/3 [==============================] - 0s 77ms/step - loss: 0.4042 - mean_absolute_error: 0.4042 - val_loss: 0.3405 - val_mean_absolute_error: 0.3405
# Epoch 4/100
# 3/3 [==============================] - 0s 66ms/step - loss: 0.3335 - mean_absolute_error: 0.3335 - val_loss: 0.1791 - val_mean_absolute_error: 0.1791
# Epoch 5/100
# 3/3 [==============================] - 0s 60ms/step - loss: 0.2340 - mean_absolute_error: 0.2340 - val_loss: 0.1683 - val_mean_absolute_error: 0.1683
# Epoch 6/100
# 3/3 [==============================] - 0s 70ms/step - loss: 0.2129 - mean_absolute_error: 0.2129 - val_loss: 0.1538 - val_mean_absolute_error: 0.1538
# Epoch 7/100
# 3/3 [==============================] - 0s 75ms/step - loss: 0.1699 - mean_absolute_error: 0.1699 - val_loss: 0.1853 - val_mean_absolute_error: 0.1853
# Epoch 8/100
# 3/3 [==============================] - 0s 66ms/step - loss: 0.1693 - mean_absolute_error: 0.1693 - val_loss: 0.1380 - val_mean_absolute_error: 0.1380
# Epoch 9/100
# 3/3 [==============================] - 0s 74ms/step - loss: 0.1941 - mean_absolute_error: 0.1941 - val_loss: 0.1168 - val_mean_absolute_error: 0.1168
# Epoch 10/100
# 3/3 [==============================] - 0s 60ms/step - loss: 0.1526 - mean_absolute_error: 0.1526 - val_loss: 0.2662 - val_mean_absolute_error: 0.2662
# Epoch 11/100
# 3/3 [==============================] - 0s 67ms/step - loss: 0.1268 - mean_absolute_error: 0.1268 - val_loss: 0.1164 - val_mean_absolute_error: 0.1164
# Epoch 12/100
# 3/3 [==============================] - 0s 64ms/step - loss: 0.1355 - mean_absolute_error: 0.1355 - val_loss: 0.1773 - val_mean_absolute_error: 0.1773
# Epoch 13/100
# 3/3 [==============================] - 0s 70ms/step - loss: 0.1014 - mean_absolute_error: 0.1014 - val_loss: 0.1455 - val_mean_absolute_error: 0.1455
# Epoch 14/100
# 3/3 [==============================] - 0s 69ms/step - loss: 0.1027 - mean_absolute_error: 0.1027 - val_loss: 0.1879 - val_mean_absolute_error: 0.1879
# Epoch 15/100
# 3/3 [==============================] - 0s 61ms/step - loss: 0.1012 - mean_absolute_error: 0.1012 - val_loss: 0.1522 - val_mean_absolute_error: 0.1522
# Epoch 16/100
# 3/3 [==============================] - 0s 65ms/step - loss: 0.0952 - mean_absolute_error: 0.0952 - val_loss: 0.1561 - val_mean_absolute_error: 0.1561
# Epoch 17/100
# 3/3 [==============================] - 0s 60ms/step - loss: 0.0976 - mean_absolute_error: 0.0976 - val_loss: 0.1271 - val_mean_absolute_error: 0.1271
# Epoch 18/100
# 3/3 [==============================] - 0s 74ms/step - loss: 0.0997 - mean_absolute_error: 0.0997 - val_loss: 0.2204 - val_mean_absolute_error: 0.2204
# Epoch 19/100
# 3/3 [==============================] - 0s 70ms/step - loss: 0.1163 - mean_absolute_error: 0.1163 - val_loss: 0.2415 - val_mean_absolute_error: 0.2415
# Epoch 20/100
# 3/3 [==============================] - 0s 70ms/step - loss: 0.1044 - mean_absolute_error: 0.1044 - val_loss: 0.1272 - val_mean_absolute_error: 0.1272
# Epoch 21/100
# 3/3 [==============================] - 0s 63ms/step - loss: 0.1156 - mean_absolute_error: 0.1156 - val_loss: 0.1240 - val_mean_absolute_error: 0.1240
# Epoch 22/100
# 3/3 [==============================] - 0s 71ms/step - loss: 0.1194 - mean_absolute_error: 0.1194 - val_loss: 0.1875 - val_mean_absolute_error: 0.1875
# Epoch 23/100
# 3/3 [==============================] - 0s 62ms/step - loss: 0.0976 - mean_absolute_error: 0.0976 - val_loss: 0.1454 - val_mean_absolute_error: 0.1454
# Epoch 24/100
# 3/3 [==============================] - 0s 64ms/step - loss: 0.0861 - mean_absolute_error: 0.0861 - val_loss: 0.1300 - val_mean_absolute_error: 0.1300
# Epoch 25/100
# 3/3 [==============================] - 0s 62ms/step - loss: 0.0872 - mean_absolute_error: 0.0872 - val_loss: 0.2414 - val_mean_absolute_error: 0.2414
# Epoch 26/100
# 3/3 [==============================] - 0s 75ms/step - loss: 0.1275 - mean_absolute_error: 0.1275 - val_loss: 0.1790 - val_mean_absolute_error: 0.1790
# Epoch 27/100
# 3/3 [==============================] - 0s 57ms/step - loss: 0.0872 - mean_absolute_error: 0.0872 - val_loss: 0.1338 - val_mean_absolute_error: 0.1338
# Epoch 28/100
# 3/3 [==============================] - 0s 64ms/step - loss: 0.1476 - mean_absolute_error: 0.1476 - val_loss: 0.1315 - val_mean_absolute_error: 0.1315
# Epoch 29/100
# 3/3 [==============================] - 0s 79ms/step - loss: 0.1098 - mean_absolute_error: 0.1098 - val_loss: 0.2578 - val_mean_absolute_error: 0.2578
# Epoch 30/100
# 3/3 [==============================] - 0s 80ms/step - loss: 0.1161 - mean_absolute_error: 0.1161 - val_loss: 0.1284 - val_mean_absolute_error: 0.1284
# Epoch 31/100
# 3/3 [==============================] - 0s 78ms/step - loss: 0.1152 - mean_absolute_error: 0.1152 - val_loss: 0.1291 - val_mean_absolute_error: 0.1291
# Epoch 32/100
# 3/3 [==============================] - 0s 74ms/step - loss: 0.1149 - mean_absolute_error: 0.1149 - val_loss: 0.2080 - val_mean_absolute_error: 0.2080
# Epoch 33/100
# 3/3 [==============================] - 0s 72ms/step - loss: 0.1183 - mean_absolute_error: 0.1183 - val_loss: 0.1755 - val_mean_absolute_error: 0.1755
# Epoch 34/100
# 3/3 [==============================] - 0s 64ms/step - loss: 0.0961 - mean_absolute_error: 0.0961 - val_loss: 0.1279 - val_mean_absolute_error: 0.1279
# Epoch 35/100
# 3/3 [==============================] - 0s 76ms/step - loss: 0.1211 - mean_absolute_error: 0.1211 - val_loss: 0.1350 - val_mean_absolute_error: 0.1350
# Epoch 36/100
# 3/3 [==============================] - 0s 60ms/step - loss: 0.0940 - mean_absolute_error: 0.0940 - val_loss: 0.2536 - val_mean_absolute_error: 0.2536
# Epoch 37/100
# 3/3 [==============================] - 0s 61ms/step - loss: 0.1198 - mean_absolute_error: 0.1198 - val_loss: 0.1604 - val_mean_absolute_error: 0.1604
# Epoch 38/100
# 3/3 [==============================] - 0s 75ms/step - loss: 0.0892 - mean_absolute_error: 0.0892 - val_loss: 0.1331 - val_mean_absolute_error: 0.1331
# Epoch 39/100
# 3/3 [==============================] - 0s 64ms/step - loss: 0.0988 - mean_absolute_error: 0.0988 - val_loss: 0.1596 - val_mean_absolute_error: 0.1596
# Epoch 40/100
# ...
# Epoch 5/100
# 3/3 [==============================] - 0s 76ms/step - loss: 0.1609 - mean_absolute_error: 0.1609 - val_loss: 0.4370 - val_mean_absolute_error: 0.4370
# Epoch 6/100
# 3/3 [==============================] - 0s 75ms/step - loss: 0.0796 - mean_absolute_error: 0.0796 - val_loss: 0.2623 - val_mean_absolute_error: 0.2623
# Epoch 7/100
# 3/3 [==============================] - 0s 73ms/step - loss: 0.1280 - mean_absolute_error: 0.1280 - val_loss: 0.3121 - val_mean_absolute_error: 0.3121
# Epoch 8/100
# 3/3 [==============================] - 0s 77ms/step - loss: 0.0809 - mean_absolute_error: 0.0809 - val_loss: 0.4568 - val_mean_absolute_error: 0.4568
# Epoch 9/100
# 3/3 [==============================] - 0s 67ms/step - loss: 0.1004 - mean_absolute_error: 0.1004 - val_loss: 0.4360 - val_mean_absolute_error: 0.4360
# Epoch 10/100
# 3/3 [==============================] - 0s 78ms/step - loss: 0.0800 - mean_absolute_error: 0.0800 - val_loss: 0.3373 - val_mean_absolute_error: 0.3373
# Epoch 11/100
# 3/3 [==============================] - 0s 71ms/step - loss: 0.0831 - mean_absolute_error: 0.0831 - val_loss: 0.3480 - val_mean_absolute_error: 0.3480
# Epoch 12/100
# 3/3 [==============================] - 0s 63ms/step - loss: 0.0740 - mean_absolute_error: 0.0740 - val_loss: 0.4254 - val_mean_absolute_error: 0.4254
# Epoch 13/100
# 3/3 [==============================] - 0s 79ms/step - loss: 0.0787 - mean_absolute_error: 0.0787 - val_loss: 0.4086 - val_mean_absolute_error: 0.4086
# Epoch 14/100
# 3/3 [==============================] - 0s 75ms/step - loss: 0.0580 - mean_absolute_error: 0.0580 - val_loss: 0.3682 - val_mean_absolute_error: 0.3682
# Epoch 15/100
# 3/3 [==============================] - 0s 63ms/step - loss: 0.0665 - mean_absolute_error: 0.0665 - val_loss: 0.3747 - val_mean_absolute_error: 0.3747
# Epoch 16/100
# 3/3 [==============================] - 0s 64ms/step - loss: 0.0596 - mean_absolute_error: 0.0596 - val_loss: 0.3934 - val_mean_absolute_error: 0.3934
# Epoch 17/100
# 3/3 [==============================] - 0s 77ms/step - loss: 0.0687 - mean_absolute_error: 0.0687 - val_loss: 0.3954 - val_mean_absolute_error: 0.3954
# Epoch 18/100
# 3/3 [==============================] - 0s 77ms/step - loss: 0.0690 - mean_absolute_error: 0.0690 - val_loss: 0.3787 - val_mean_absolute_error: 0.3787
# Epoch 19/100
# 3/3 [==============================] - 0s 71ms/step - loss: 0.0660 - mean_absolute_error: 0.0660 - val_loss: 0.3843 - val_mean_absolute_error: 0.3843
# Epoch 20/100
# 3/3 [==============================] - 0s 67ms/step - loss: 0.0650 - mean_absolute_error: 0.0650 - val_loss: 0.3888 - val_mean_absolute_error: 0.3888
# Epoch 21/100
# 3/3 [==============================] - 0s 74ms/step - loss: 0.0633 - mean_absolute_error: 0.0633 - val_loss: 0.3904 - val_mean_absolute_error: 0.3904
# Epoch 22/100
# 3/3 [==============================] - 0s 65ms/step - loss: 0.0571 - mean_absolute_error: 0.0571 - val_loss: 0.3886 - val_mean_absolute_error: 0.3886
# Epoch 23/100
# 3/3 [==============================] - 0s 63ms/step - loss: 0.0631 - mean_absolute_error: 0.0631 - val_loss: 0.4056 - val_mean_absolute_error: 0.4056
# Epoch 24/100
# 3/3 [==============================] - 0s 71ms/step - loss: 0.0691 - mean_absolute_error: 0.0691 - val_loss: 0.4177 - val_mean_absolute_error: 0.4177
# Epoch 25/100
# 3/3 [==============================] - 0s 77ms/step - loss: 0.0589 - mean_absolute_error: 0.0589 - val_loss: 0.3737 - val_mean_absolute_error: 0.3737
# Epoch 26/100
# 3/3 [==============================] - 0s 77ms/step - loss: 0.0676 - mean_absolute_error: 0.0676 - val_loss: 0.3652 - val_mean_absolute_error: 0.3652
# Epoch 27/100
# 3/3 [==============================] - 0s 68ms/step - loss: 0.0694 - mean_absolute_error: 0.0694 - val_loss: 0.3935 - val_mean_absolute_error: 0.3935
# Epoch 28/100
# 3/3 [==============================] - 0s 82ms/step - loss: 0.0722 - mean_absolute_error: 0.0722 - val_loss: 0.3801 - val_mean_absolute_error: 0.3801
# Epoch 29/100
# 3/3 [==============================] - 0s 75ms/step - loss: 0.0630 - mean_absolute_error: 0.0630 - val_loss: 0.3506 - val_mean_absolute_error: 0.3506
# Epoch 30/100
# 3/3 [==============================] - 0s 64ms/step - loss: 0.0561 - mean_absolute_error: 0.0561 - val_loss: 0.4058 - val_mean_absolute_error: 0.4058
# Epoch 31/100
# 3/3 [==============================] - 0s 64ms/step - loss: 0.0603 - mean_absolute_error: 0.0603 - val_loss: 0.3933 - val_mean_absolute_error: 0.3933
# Epoch 32/100
# 3/3 [==============================] - 0s 76ms/step - loss: 0.0589 - mean_absolute_error: 0.0589 - val_loss: 0.3612 - val_mean_absolute_error: 0.3612
# Epoch 33/100
# 3/3 [==============================] - 0s 71ms/step - loss: 0.0667 - mean_absolute_error: 0.0667 - val_loss: 0.3691 - val_mean_absolute_error: 0.3691
# Epoch 34/100
# 3/3 [==============================] - 0s 79ms/step - loss: 0.0712 - mean_absolute_error: 0.0712 - val_loss: 0.3790 - val_mean_absolute_error: 0.3790
# Epoch 35/100
# 3/3 [==============================] - 0s 73ms/step - loss: 0.0670 - mean_absolute_error: 0.0670 - val_loss: 0.3761 - val_mean_absolute_error: 0.3761
# Epoch 36/100
# 3/3 [==============================] - 0s 65ms/step - loss: 0.0603 - mean_absolute_error: 0.0603 - val_loss: 0.3745 - val_mean_absolute_error: 0.3745
# Epoch 37/100
# 3/3 [==============================] - 0s 65ms/step - loss: 0.0618 - mean_absolute_error: 0.0618 - val_loss: 0.4004 - val_mean_absolute_error: 0.4004
# Epoch 38/100
# 3/3 [==============================] - 0s 83ms/step - loss: 0.0636 - mean_absolute_error: 0.0636 - val_loss: 0.3735 - val_mean_absolute_error: 0.3735
# Epoch 39/100
# 3/3 [==============================] - 0s 82ms/step - loss: 0.0626 - mean_absolute_error: 0.0626 - val_loss: 0.3616 - val_mean_absolute_error: 0.3616
# Epoch 40/100
# 3/3 [==============================] - 0s 74ms/step - loss: 0.0664 - mean_absolute_error: 0.0664 - val_loss: 0.3897 - val_mean_absolute_error: 0.3897
# Epoch 41/100
# 3/3 [==============================] - 0s 64ms/step - loss: 0.0548 - mean_absolute_error: 0.0548 - val_loss: 0.3364 - val_mean_absolute_error: 0.3364
# Epoch 42/100
# 3/3 [==============================] - 0s 68ms/step - loss: 0.0698 - mean_absolute_error: 0.0698 - val_loss: 0.3579 - val_mean_absolute_error: 0.3579
# Epoch 43/100
# 3/3 [==============================] - 0s 82ms/step - loss: 0.0642 - mean_absolute_error: 0.0642 - val_loss: 0.4176 - val_mean_absolute_error: 0.4176
# Epoch 44/100
# 3/3 [==============================] - 0s 79ms/step - loss: 0.0751 - mean_absolute_error: 0.0751 - val_loss: 0.3877 - val_mean_absolute_error: 0.3877
# Epoch 45/100
# 3/3 [==============================] - 0s 88ms/step - loss: 0.0660 - mean_absolute_error: 0.0660 - val_loss: 0.3949 - val_mean_absolute_error: 0.3949
# Epoch 46/100
# 3/3 [==============================] - 0s 69ms/step - loss: 0.0616 - mean_absolute_error: 0.0616 - val_loss: 0.3658 - val_mean_absolute_error: 0.3658
# Epoch 47/100
# 3/3 [==============================] - 0s 73ms/step - loss: 0.0626 - mean_absolute_error: 0.0626 - val_loss: 0.3365 - val_mean_absolute_error: 0.3365
# Epoch 48/100
# 3/3 [==============================] - 0s 81ms/step - loss: 0.0690 - mean_absolute_error: 0.0690 - val_loss: 0.4012 - val_mean_absolute_error: 0.4012
# Epoch 49/100
# 3/3 [==============================] - 0s 74ms/step - loss: 0.0665 - mean_absolute_error: 0.0665 - val_loss: 0.3780 - val_mean_absolute_error: 0.3780
# Epoch 50/100
# 3/3 [==============================] - 0s 60ms/step - loss: 0.0553 - mean_absolute_error: 0.0553 - val_loss: 0.3572 - val_mean_absolute_error: 0.3572
# Epoch 51/100
# 3/3 [==============================] - 0s 65ms/step - loss: 0.0578 - mean_absolute_error: 0.0578 - val_loss: 0.3706 - val_mean_absolute_error: 0.3706
# Epoch 52/100
# 3/3 [==============================] - 0s 85ms/step - loss: 0.0551 - mean_absolute_error: 0.0551 - val_loss: 0.3785 - val_mean_absolute_error: 0.3785
# Epoch 53/100
# 3/3 [==============================] - 0s 69ms/step - loss: 0.0635 - mean_absolute_error: 0.0635 - val_loss: 0.3641 - val_mean_absolute_error: 0.3641
# Epoch 54/100
# 3/3 [==============================] - 0s 85ms/step - loss: 0.0528 - mean_absolute_error: 0.0528 - val_loss: 0.3658 - val_mean_absolute_error: 0.3658
# Epoch 55/100
# 3/3 [==============================] - 0s 82ms/step - loss: 0.0631 - mean_absolute_error: 0.0631 - val_loss: 0.3518 - val_mean_absolute_error: 0.3518
# Epoch 56/100
# 3/3 [==============================] - 0s 81ms/step - loss: 0.0587 - mean_absolute_error: 0.0587 - val_loss: 0.3645 - val_mean_absolute_error: 0.3645
# Epoch 57/100
# 3/3 [==============================] - 0s 75ms/step - loss: 0.0571 - mean_absolute_error: 0.0571 - val_loss: 0.3449 - val_mean_absolute_error: 0.3449
# Epoch 58/100
# 3/3 [==============================] - 0s 65ms/step - loss: 0.0596 - mean_absolute_error: 0.0596 - val_loss: 0.3432 - val_mean_absolute_error: 0.3432
# Epoch 59/100
# 3/3 [==============================] - 0s 71ms/step - loss: 0.0607 - mean_absolute_error: 0.0607 - val_loss: 0.3915 - val_mean_absolute_error: 0.3915
# Epoch 60/100
# 3/3 [==============================] - 0s 63ms/step - loss: 0.0759 - mean_absolute_error: 0.0759 - val_loss: 0.3788 - val_mean_absolute_error: 0.3788
# Epoch 61/100
# 3/3 [==============================] - 0s 61ms/step - loss: 0.0624 - mean_absolute_error: 0.0624 - val_loss: 0.2931 - val_mean_absolute_error: 0.2931
# Epoch 62/100
# 3/3 [==============================] - 0s 79ms/step - loss: 0.0897 - mean_absolute_error: 0.0897 - val_loss: 0.3617 - val_mean_absolute_error: 0.3617
# Epoch 63/100
# 3/3 [==============================] - 0s 76ms/step - loss: 0.0679 - mean_absolute_error: 0.0679 - val_loss: 0.3992 - val_mean_absolute_error: 0.3992
# Epoch 64/100
# 3/3 [==============================] - 0s 80ms/step - loss: 0.0712 - mean_absolute_error: 0.0712 - val_loss: 0.3185 - val_mean_absolute_error: 0.3185
# Epoch 65/100
# 3/3 [==============================] - 0s 76ms/step - loss: 0.0799 - mean_absolute_error: 0.0799 - val_loss: 0.3831 - val_mean_absolute_error: 0.3831
# Epoch 66/100
# 3/3 [==============================] - 0s 73ms/step - loss: 0.0649 - mean_absolute_error: 0.0649 - val_loss: 0.3813 - val_mean_absolute_error: 0.3813
# Epoch 67/100
# 3/3 [==============================] - 0s 73ms/step - loss: 0.0666 - mean_absolute_error: 0.0666 - val_loss: 0.3237 - val_mean_absolute_error: 0.3237
# Epoch 68/100
# 3/3 [==============================] - 0s 67ms/step - loss: 0.0627 - mean_absolute_error: 0.0627 - val_loss: 0.3837 - val_mean_absolute_error: 0.3837
# Epoch 69/100
# 3/3 [==============================] - 0s 74ms/step - loss: 0.0658 - mean_absolute_error: 0.0658 - val_loss: 0.3753 - val_mean_absolute_error: 0.3753
# Epoch 70/100
# 3/3 [==============================] - 0s 61ms/step - loss: 0.0653 - mean_absolute_error: 0.0653 - val_loss: 0.3072 - val_mean_absolute_error: 0.3072
# Epoch 71/100
# 3/3 [==============================] - 0s 75ms/step - loss: 0.0831 - mean_absolute_error: 0.0831 - val_loss: 0.3941 - val_mean_absolute_error: 0.3941
# Epoch 72/100
# 3/3 [==============================] - 0s 79ms/step - loss: 0.0735 - mean_absolute_error: 0.0735 - val_loss: 0.4112 - val_mean_absolute_error: 0.4112
# Epoch 73/100
# 3/3 [==============================] - 0s 64ms/step - loss: 0.0594 - mean_absolute_error: 0.0594 - val_loss: 0.3207 - val_mean_absolute_error: 0.3207
# Epoch 74/100
# 3/3 [==============================] - 0s 75ms/step - loss: 0.0695 - mean_absolute_error: 0.0695 - val_loss: 0.3344 - val_mean_absolute_error: 0.3344
# Epoch 75/100
# 3/3 [==============================] - 0s 63ms/step - loss: 0.0626 - mean_absolute_error: 0.0626 - val_loss: 0.4155 - val_mean_absolute_error: 0.4155
# Epoch 76/100
# 3/3 [==============================] - 0s 64ms/step - loss: 0.0809 - mean_absolute_error: 0.0809 - val_loss: 0.3960 - val_mean_absolute_error: 0.3960
# Epoch 77/100
# 3/3 [==============================] - 0s 62ms/step - loss: 0.0689 - mean_absolute_error: 0.0689 - val_loss: 0.3340 - val_mean_absolute_error: 0.3340
# Epoch 78/100
# 3/3 [==============================] - 0s 67ms/step - loss: 0.0672 - mean_absolute_error: 0.0672 - val_loss: 0.3603 - val_mean_absolute_error: 0.3603
# Epoch 79/100
# 3/3 [==============================] - 0s 84ms/step - loss: 0.0613 - mean_absolute_error: 0.0613 - val_loss: 0.3875 - val_mean_absolute_error: 0.3875
# Epoch 80/100
# 3/3 [==============================] - 0s 72ms/step - loss: 0.0679 - mean_absolute_error: 0.0679 - val_loss: 0.3949 - val_mean_absolute_error: 0.3949
# Epoch 81/100
# 3/3 [==============================] - 0s 72ms/step - loss: 0.0670 - mean_absolute_error: 0.0670 - val_loss: 0.3755 - val_mean_absolute_error: 0.3755
# Epoch 82/100
# 3/3 [==============================] - 0s 72ms/step - loss: 0.0604 - mean_absolute_error: 0.0604 - val_loss: 0.3488 - val_mean_absolute_error: 0.3488
# Epoch 83/100
# 3/3 [==============================] - 0s 79ms/step - loss: 0.0647 - mean_absolute_error: 0.0647 - val_loss: 0.3563 - val_mean_absolute_error: 0.3563
# Epoch 84/100
# 3/3 [==============================] - 0s 60ms/step - loss: 0.0612 - mean_absolute_error: 0.0612 - val_loss: 0.3505 - val_mean_absolute_error: 0.3505
# Epoch 85/100
# 3/3 [==============================] - 0s 65ms/step - loss: 0.0630 - mean_absolute_error: 0.0630 - val_loss: 0.3373 - val_mean_absolute_error: 0.3373
# Epoch 86/100
# 3/3 [==============================] - 0s 78ms/step - loss: 0.0617 - mean_absolute_error: 0.0617 - val_loss: 0.3565 - val_mean_absolute_error: 0.3565
# Epoch 87/100
# 3/3 [==============================] - 0s 78ms/step - loss: 0.0614 - mean_absolute_error: 0.0614 - val_loss: 0.3444 - val_mean_absolute_error: 0.3444
# Epoch 88/100
# 3/3 [==============================] - 0s 79ms/step - loss: 0.0577 - mean_absolute_error: 0.0577 - val_loss: 0.3410 - val_mean_absolute_error: 0.3410
# Epoch 89/100
# 3/3 [==============================] - 0s 76ms/step - loss: 0.0605 - mean_absolute_error: 0.0605 - val_loss: 0.3428 - val_mean_absolute_error: 0.3428
# Epoch 90/100
# 3/3 [==============================] - 0s 86ms/step - loss: 0.0526 - mean_absolute_error: 0.0526 - val_loss: 0.3194 - val_mean_absolute_error: 0.3194
# Epoch 91/100
# 3/3 [==============================] - 0s 78ms/step - loss: 0.0671 - mean_absolute_error: 0.0671 - val_loss: 0.3284 - val_mean_absolute_error: 0.3284
# Epoch 92/100
# 3/3 [==============================] - 0s 76ms/step - loss: 0.0570 - mean_absolute_error: 0.0570 - val_loss: 0.3489 - val_mean_absolute_error: 0.3489
# Epoch 93/100
# 3/3 [==============================] - 0s 63ms/step - loss: 0.0510 - mean_absolute_error: 0.0510 - val_loss: 0.3232 - val_mean_absolute_error: 0.3232
# Epoch 94/100
# 3/3 [==============================] - 0s 62ms/step - loss: 0.0568 - mean_absolute_error: 0.0568 - val_loss: 0.3221 - val_mean_absolute_error: 0.3221
# Epoch 95/100
# 3/3 [==============================] - 0s 77ms/step - loss: 0.0657 - mean_absolute_error: 0.0657 - val_loss: 0.3460 - val_mean_absolute_error: 0.3460
# Epoch 96/100
# 3/3 [==============================] - 0s 74ms/step - loss: 0.0540 - mean_absolute_error: 0.0540 - val_loss: 0.3500 - val_mean_absolute_error: 0.3500
# Epoch 97/100
# 3/3 [==============================] - 0s 62ms/step - loss: 0.0608 - mean_absolute_error: 0.0608 - val_loss: 0.3334 - val_mean_absolute_error: 0.3334
# Epoch 98/100
# 3/3 [==============================] - 0s 67ms/step - loss: 0.0654 - mean_absolute_error: 0.0654 - val_loss: 0.3444 - val_mean_absolute_error: 0.3444
# Epoch 99/100
# 3/3 [==============================] - 0s 81ms/step - loss: 0.0613 - mean_absolute_error: 0.0613 - val_loss: 0.3037 - val_mean_absolute_error: 0.3037
# Epoch 100/100
# 3/3 [==============================] - 0s 85ms/step - loss: 0.0626 - mean_absolute_error: 0.0626 - val_loss: 0.3321 - val_mean_absolute_error: 0.3321
# 輸入變數維度 (649, 5, 1)
# 預測變數維度 (649,)
# 第Y個被預測日之前ref_day天每天正規化股價
# [[0.23067496]
#  [0.25815628]
#  [0.22780529]
#  [0.24800255]
#  [0.25009949]]
# 第Y個預測日之正規化股價
# 0.26367465742259333
# 21/21 [==============================] - 0s 6ms/step - loss: 0.1893 - mean_absolute_error: 0.1893

# %%
rdf
# Out:
#            TSLA     4958.TW     2330.TW  ...  600885.SS        DAN         TEL
# 0    286.317902   73.132690  236.034012  ...  24.314190  16.465437   99.205132
# 1    286.321320   73.130211  236.019501  ...  24.288130  16.332222   99.039604
# 2    286.330933   73.120735  235.992294  ...  24.380196  16.397314   99.190781
# 3    286.335541   73.117180  236.000748  ...  24.576969  16.296656   99.191254
# 4    286.336487   73.130020  236.012772  ...  24.805611  16.042294   99.358391
# ..          ...         ...         ...  ...        ...        ...         ...
# 644  641.249878  119.553459  601.029175  ...  49.737938  21.405432  117.814484
# 645  637.428345  117.624168  597.572266  ...  50.805599  21.335461  117.307060
# 646  641.813477  116.161293  597.094788  ...  50.460331  21.366543  117.509941
# 647  644.685608  115.323677  597.184875  ...  50.551254  21.706816  118.483505
# 648  637.943787  115.374588  599.672485  ...  51.032314  21.814205  118.551384
#
# [649 rows x 10 columns]

# %%
import os
os.chdir('/content/gdrive/MyDrive/Colab Notebooks/LSTM預測結果')
print(os.getcwd() )#获取当前工作路径
timenow= time.strftime("%Y-%m-%d %H:%M:%S", time.localtime()) 
type(timenow) #str

outstr= 'result'+ timenow + '.csv'
rdf.to_csv(outstr) #相对位置，保存在getwcd()获得的路径下

outstr
# Out:
# /content/gdrive/MyDrive/Colab Notebooks/LSTM預測結果
# 'result2021-05-12 09:07:31.csv'
